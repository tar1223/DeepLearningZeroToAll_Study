# %%
import tensorflow as tf

# %%
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalizing data
x_train, x_test = x_train / 255.0, x_test / 255.0

print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
# change data shape
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2])

# %%
# change result to one-hot encoding
# in tf1, one_hot=True in read_data_sets("MNIST_data/", one_hot=True)
# took care of it, but here we need to manually convert them
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units = 10, input_dim = 784, activation = 'softmax'))
tf.model.compile(loss = 'categorical_crossentropy', optimizer = tf.optimizers.Adam(0.001), metrics = ['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                7850
#
# =================================================================
# Total params: 7850 (30.66 KB)
# Trainable params: 7850 (30.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = tf.model.fit(x_train, y_train, batch_size = batch_size, epochs = training_epochs)
# Out:
# Epoch 1/15
# 600/600 [==============================] - 3s 4ms/step - loss: 0.6413 - accuracy: 0.8384
# Epoch 2/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.3469 - accuracy: 0.9061
# Epoch 3/15
# 600/600 [==============================] - 3s 5ms/step - loss: 0.3100 - accuracy: 0.9147
# Epoch 4/15
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2923 - accuracy: 0.9187
# Epoch 5/15
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2820 - accuracy: 0.9213
# Epoch 6/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2748 - accuracy: 0.9235
# Epoch 7/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2692 - accuracy: 0.9258
# Epoch 8/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2653 - accuracy: 0.9261
# Epoch 9/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2623 - accuracy: 0.9266
# Epoch 10/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2595 - accuracy: 0.9282
# Epoch 11/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2568 - accuracy: 0.9283
# Epoch 12/15
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2547 - accuracy: 0.9294
# Epoch 13/15
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2531 - accuracy: 0.9291
# Epoch 14/15
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2514 - accuracy: 0.9301
# Epoch 15/15
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2496 - accuracy: 0.9315

# %%
predictions = tf.model.predict(x_test)
print('Prediction: \n', predictions)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# Prediction:
#  [[2.34151889e-06 9.54593956e-12 1.15401190e-05 ... 9.94011164e-01
#   2.13698167e-05 3.24560446e-04]
#  [1.44698948e-04 1.96712881e-06 9.95867193e-01 ... 9.97893072e-18
#   3.09076240e-05 3.98110466e-14]
#  [1.54700592e-06 9.79881704e-01 1.19890161e-02 ... 8.09040270e-04
#   2.91900290e-03 2.14750820e-04]
#  ...
#  [1.41119445e-08 9.49163947e-09 9.25796121e-06 ... 2.22834363e-03
#   1.21075502e-02 2.20240913e-02]
#  [1.85032917e-07 3.07938137e-07 3.48131266e-07 ... 1.69277740e-07
#   1.25097455e-02 1.56933012e-07]
#  [1.14920169e-06 6.82232184e-14 1.19364697e-04 ... 1.45848492e-12
#   4.54108147e-08 7.36406283e-11]]

# %%
score = tf.model.evaluate(x_train, y_train)
print('Accuracy: ', score[1])
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2454 - accuracy: 0.9327
# Accuracy:  0.932699978351593
