# %%
import numpy as np
import tensorflow as tf

# %%
idx2char = ['h', 'i', 'e', 'l', 'o']
# Teach hello: hihell -> ihello
# x_data = [[0, 1, 0, 2, 3, 3]] # hihell
y_data = [[1, 0, 2, 3, 3, 4]] # ihello

# %%
num_classes = 5
input_dim = 5 # one-hot size, same as hidden_size to directly predict one-hot
sequence_length = 6 # |ihello| == 6
learning_rate = 0.1

# %%
x_one_hot = np.array([[[1, 0, 0, 0, 0], # h 0
                       [0, 1, 0, 0, 0], # i 1
                       [1, 0, 0, 0 ,0], # h 0
                       [0, 0, 1, 0, 0], # e 2
                       [0, 0, 0, 1, 0], # l 3
                       [0, 0, 0, 1, 0]]], # l 3
                     dtype = np.float32)

y_one_hot = tf.keras.utils.to_categorical(y_data, num_classes = num_classes)
print(x_one_hot.shape)
print(y_one_hot.shape)
# Out:
# (1, 6, 5)
# (1, 6, 5)

# %%
tf.model = tf.keras.Sequential()

# make cell and add it to RNN layer
# input_shape = (1,6,5) => number of sequence (batch), length of sequence, size of input dim
cell = tf.keras.layers.LSTMCell(units = num_classes, input_shape = (sequence_length, input_dim))
tf.model.add(tf.keras.layers.RNN(cell = cell, return_sequences = True))

# fully connected layer
tf.model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units = num_classes, activation = 'softmax')))

# %%
tf.model.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(lr = learning_rate),
                 metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
# train
tf.model.fit(x_one_hot, y_one_hot, epochs = 50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 1.6161 - accuracy: 0.1667
# Epoch 2/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6148 - accuracy: 0.1667
# Epoch 3/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6135 - accuracy: 0.3333
# Epoch 4/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6122 - accuracy: 0.3333
# Epoch 5/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6109 - accuracy: 0.3333
# Epoch 6/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6096 - accuracy: 0.3333
# Epoch 7/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6084 - accuracy: 0.3333
# Epoch 8/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6071 - accuracy: 0.3333
# Epoch 9/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.6059 - accuracy: 0.3333
# Epoch 10/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6046 - accuracy: 0.3333
# Epoch 11/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6034 - accuracy: 0.3333
# Epoch 12/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6021 - accuracy: 0.3333
# Epoch 13/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6009 - accuracy: 0.3333
# Epoch 14/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5997 - accuracy: 0.3333
# Epoch 15/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.5984 - accuracy: 0.3333
# Epoch 16/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5972 - accuracy: 0.3333
# Epoch 17/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5960 - accuracy: 0.3333
# Epoch 18/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5948 - accuracy: 0.3333
# Epoch 19/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.5936 - accuracy: 0.3333
# Epoch 20/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5924 - accuracy: 0.3333
# Epoch 21/50
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5912 - accuracy: 0.3333
# Epoch 22/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5900 - accuracy: 0.3333
# Epoch 23/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5888 - accuracy: 0.3333
# Epoch 24/50
# 1/1 [==============================] - 0s 23ms/step - loss: 1.5877 - accuracy: 0.3333
# Epoch 25/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5865 - accuracy: 0.3333
# Epoch 26/50
# 1/1 [==============================] - 0s 31ms/step - loss: 1.5853 - accuracy: 0.5000
# Epoch 27/50
# 1/1 [==============================] - 0s 29ms/step - loss: 1.5841 - accuracy: 0.5000
# Epoch 28/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.5829 - accuracy: 0.5000
# Epoch 29/50
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5817 - accuracy: 0.5000
# Epoch 30/50
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5806 - accuracy: 0.5000
# Epoch 31/50
# 1/1 [==============================] - 0s 32ms/step - loss: 1.5794 - accuracy: 0.5000
# Epoch 32/50
# 1/1 [==============================] - 0s 25ms/step - loss: 1.5782 - accuracy: 0.5000
# Epoch 33/50
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5770 - accuracy: 0.5000
# Epoch 34/50
# 1/1 [==============================] - 0s 27ms/step - loss: 1.5759 - accuracy: 0.5000
# Epoch 35/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5747 - accuracy: 0.5000
# Epoch 36/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5735 - accuracy: 0.5000
# Epoch 37/50
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5723 - accuracy: 0.5000
# Epoch 38/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.5711 - accuracy: 0.5000
# Epoch 39/50
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5699 - accuracy: 0.5000
# Epoch 40/50
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5688 - accuracy: 0.5000
# Epoch 41/50
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5676 - accuracy: 0.5000
# Epoch 42/50
# 1/1 [==============================] - 0s 23ms/step - loss: 1.5664 - accuracy: 0.5000
# Epoch 43/50
# 1/1 [==============================] - 0s 22ms/step - loss: 1.5652 - accuracy: 0.5000
# Epoch 44/50
# 1/1 [==============================] - 0s 26ms/step - loss: 1.5640 - accuracy: 0.5000
# Epoch 45/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5628 - accuracy: 0.5000
# Epoch 46/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5615 - accuracy: 0.5000
# Epoch 47/50
# 1/1 [==============================] - 0s 17ms/step - loss: 1.5603 - accuracy: 0.5000
# Epoch 48/50
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5591 - accuracy: 0.5000
# Epoch 49/50
# 1/1 [==============================] - 0s 14ms/step - loss: 1.5579 - accuracy: 0.5000
# Epoch 50/50
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5567 - accuracy: 0.5000

# %%
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rnn (RNN)                   (None, 6, 5)              220
#
#  time_distributed (TimeDist  (None, 6, 5)              30
#  ributed)
#
# =================================================================
# Total params: 250 (1000.00 Byte)
# Trainable params: 250 (1000.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
predictions = tf.model.predict(x_one_hot)

for i, prediction in enumerate(predictions):
  print(prediction)
  # print char using argmax, dict
  result_str = [idx2char[c] for c in np.argmax(prediction, axis = 1)]
  print("\t Prediction str: ", ''.join(result_str))
# Out:
# 1/1 [==============================] - 0s 196ms/step
# [[0.2028903  0.17887199 0.2143928  0.20995218 0.19389269]
#  [0.201662   0.18107739 0.21092425 0.21084285 0.19549356]
#  [0.20391156 0.16808328 0.2258795  0.20585793 0.1962677 ]
#  [0.20523943 0.1804418  0.21473265 0.21153225 0.18805382]
#  [0.18951093 0.17928404 0.20028003 0.22213216 0.20879279]
#  [0.17484833 0.17996706 0.1866749  0.22735311 0.23115659]]
# 	 Prediction str:  eeeelo
