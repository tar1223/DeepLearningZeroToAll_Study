# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
batch_size = 128
num_classes = 10
epochs = 12

# %%
# prepare data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
# build model
model = Sequential()

model.add(Dense(256, input_dim = 784, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(256, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(256, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(256, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dropout(0.3))

model.add(Dense(num_classes, activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_split = 0.2)
# Out:
# Epoch 1/12
# 375/375 [==============================] - 15s 34ms/step - loss: 0.4645 - accuracy: 0.8540 - val_loss: 0.1465 - val_accuracy: 0.9556
# Epoch 2/12
# 375/375 [==============================] - 9s 24ms/step - loss: 0.1915 - accuracy: 0.9444 - val_loss: 0.1149 - val_accuracy: 0.9668
# Epoch 3/12
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1492 - accuracy: 0.9559 - val_loss: 0.1025 - val_accuracy: 0.9688
# Epoch 4/12
# 375/375 [==============================] - 7s 19ms/step - loss: 0.1237 - accuracy: 0.9645 - val_loss: 0.0938 - val_accuracy: 0.9728
# Epoch 5/12
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1067 - accuracy: 0.9689 - val_loss: 0.0896 - val_accuracy: 0.9753
# Epoch 6/12
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0977 - accuracy: 0.9709 - val_loss: 0.0921 - val_accuracy: 0.9753
# Epoch 7/12
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0876 - accuracy: 0.9744 - val_loss: 0.0911 - val_accuracy: 0.9745
# Epoch 8/12
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0791 - accuracy: 0.9762 - val_loss: 0.0840 - val_accuracy: 0.9768
# Epoch 9/12
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0715 - accuracy: 0.9784 - val_loss: 0.0797 - val_accuracy: 0.9782
# Epoch 10/12
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0665 - accuracy: 0.9799 - val_loss: 0.0878 - val_accuracy: 0.9769
# Epoch 11/12
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0638 - accuracy: 0.9803 - val_loss: 0.0900 - val_accuracy: 0.9771
# Epoch 12/12
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0617 - accuracy: 0.9817 - val_loss: 0.0790 - val_accuracy: 0.9801

# %%
# predict
score = model.evaluate(X_test, y_test, batch_size = batch_size)

print('\nTest loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9798
#
# Test loss: 0.07352440804243088
# Test accuracy: 0.9797999858856201
