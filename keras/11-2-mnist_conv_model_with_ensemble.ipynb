# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import *
import numpy as np
from keras.utils import to_categorical

# %%
# load mnist data
(train_data, test_data) = mnist.load_data()

# %%
# preprocess mnist data
x_train = train_data[0]
x_train = np.asarray([np.reshape(data, (28, 28, 1)) for data in x_train])
y_train = to_categorical(train_data[1])

x_test = test_data[0]
x_test = np.asarray([np.reshape(data, (28, 28, 1)) for data in x_test])
y_test_pure = test_data[1]
y_test = to_categorical(test_data[1])

# %%
# defined model
def make_conv_model_list():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), use_bias = True, activation = 'relu', padding = 'same', input_shape = (28, 28, 1)))
  model.add(MaxPool2D(2, 2))
  model.add(ZeroPadding2D(padding = (1, 1), data_format = None))
  model.add(Conv2D(64, (3, 3), use_bias = True, padding = 'same', activation = 'relu'))
  model.add(MaxPool2D(2, 2))
  model.add(Flatten())
  model.add(Dense(64, activation = 'relu'))
  model.add(Dropout(0.25))
  model.add(Dense(10, activation = 'softmax'))
  model.compile(optimizer = 'Adam', loss = 'categorical_crossentropy', metrics = ['acc'])
  model.summary()

  return model

# %%
# make  ensemble list 5
ensemble_model_list = []
ensemble_size = 5

for i in range(ensemble_size):
  this_model = make_conv_model_list()
  print(f'{i}_th model training')

  this_model.fit(x_train, y_train,
                 batch_size = 128,
                 epochs = 5,
                 verbose = 1,
                 validation_data = (x_test, y_test))

  ensemble_model_list.append(this_model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  zero_padding2d (ZeroPadding  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 64)                262208
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 281,674
# Trainable params: 281,674
# Non-trainable params: 0
# _________________________________________________________________
# 0_th model training
# Epoch 1/5
# 469/469 [==============================] - 12s 10ms/step - loss: 0.7452 - acc: 0.8152 - val_loss: 0.0777 - val_acc: 0.9778
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1582 - acc: 0.9550 - val_loss: 0.0594 - val_acc: 0.9816
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1094 - acc: 0.9680 - val_loss: 0.0488 - val_acc: 0.9867
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0819 - acc: 0.9764 - val_loss: 0.0394 - val_acc: 0.9875
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0683 - acc: 0.9796 - val_loss: 0.0409 - val_acc: 0.9881
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  zero_padding2d_1 (ZeroPaddi  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 64)                262208
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 281,674
# Trainable params: 281,674
# Non-trainable params: 0
# _________________________________________________________________
# 1_th model training
# Epoch 1/5
# 469/469 [==============================] - 5s 8ms/step - loss: 0.6658 - acc: 0.8472 - val_loss: 0.0839 - val_acc: 0.9734
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1423 - acc: 0.9585 - val_loss: 0.0653 - val_acc: 0.9809
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1000 - acc: 0.9696 - val_loss: 0.0503 - val_acc: 0.9843
# Epoch 4/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0788 - acc: 0.9762 - val_loss: 0.0470 - val_acc: 0.9863
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0656 - acc: 0.9799 - val_loss: 0.0403 - val_acc: 0.9875
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  zero_padding2d_2 (ZeroPaddi  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 64)                262208
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 281,674
# Trainable params: 281,674
# Non-trainable params: 0
# _________________________________________________________________
# 2_th model training
# Epoch 1/5
# 469/469 [==============================] - 4s 6ms/step - loss: 0.8462 - acc: 0.8064 - val_loss: 0.1104 - val_acc: 0.9676
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1726 - acc: 0.9457 - val_loss: 0.0738 - val_acc: 0.9790
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1173 - acc: 0.9642 - val_loss: 0.0621 - val_acc: 0.9811
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0894 - acc: 0.9724 - val_loss: 0.0478 - val_acc: 0.9858
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0745 - acc: 0.9776 - val_loss: 0.0443 - val_acc: 0.9873
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  zero_padding2d_3 (ZeroPaddi  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 64)                262208
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 281,674
# Trainable params: 281,674
# Non-trainable params: 0
# _________________________________________________________________
# 3_th model training
# Epoch 1/5
# 469/469 [==============================] - 5s 7ms/step - loss: 0.5501 - acc: 0.8472 - val_loss: 0.0705 - val_acc: 0.9773
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1469 - acc: 0.9559 - val_loss: 0.0502 - val_acc: 0.9844
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1045 - acc: 0.9681 - val_loss: 0.0471 - val_acc: 0.9856
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0842 - acc: 0.9745 - val_loss: 0.0478 - val_acc: 0.9869
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0715 - acc: 0.9775 - val_loss: 0.0417 - val_acc: 0.9876
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  zero_padding2d_4 (ZeroPaddi  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 64)                262208
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 281,674
# Trainable params: 281,674
# Non-trainable params: 0
# _________________________________________________________________
# 4_th model training
# Epoch 1/5
# 469/469 [==============================] - 5s 6ms/step - loss: 0.7046 - acc: 0.8557 - val_loss: 0.0819 - val_acc: 0.9767
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1370 - acc: 0.9592 - val_loss: 0.0656 - val_acc: 0.9815
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0977 - acc: 0.9709 - val_loss: 0.0451 - val_acc: 0.9868
# Epoch 4/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0755 - acc: 0.9768 - val_loss: 0.0417 - val_acc: 0.9874
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0653 - acc: 0.9806 - val_loss: 0.0478 - val_acc: 0.9863

# %%
# results of all models
all_predicted = np.zeros(y_test.shape)

for one in ensemble_model_list:
  all_predicted = all_predicted + one.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
# get final res
final_res = []

for one in all_predicted:
  final_res.append(np.argmax(one))

final_res = np.asarray(final_res)

entire = y_test_pure.shape[0]

ele = 0

for one in range(entire):
  if(y_test_pure[one] == final_res[one]):
    ele = ele + 1

res_acc = ele / entire

print('final result test accuracy:', res_acc)
# Out:
# final result test accuracy: 0.991
