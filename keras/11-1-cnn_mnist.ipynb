# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras import backend as K

import numpy as np

# %%
batch_size = 128
nb_classes = 10
nb_epoch = 12

# %%
# input image dimensions
img_rows, img_cols = 28, 28
# number of convolutional filters to use
nb_filters = 32
# size of pooling area for max pooling
pool_size = (2, 2)
# convolution kernel size
kernel_size = (3, 3)

# %%
# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = Sequential()

model.add(Conv2D(nb_filters, kernel_size, padding = 'valid', input_shape = input_shape))
model.add(Activation('relu'))
model.add(Conv2D(nb_filters, kernel_size))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adadelta',
              metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size = batch_size, epochs = nb_epoch,
          verbose = 1, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/12
# 469/469 [==============================] - 10s 12ms/step - loss: 2.2850 - accuracy: 0.1358 - val_loss: 2.2448 - val_accuracy: 0.2429
# Epoch 2/12
# 469/469 [==============================] - 5s 11ms/step - loss: 2.2311 - accuracy: 0.2104 - val_loss: 2.1830 - val_accuracy: 0.4069
# Epoch 3/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.1720 - accuracy: 0.2816 - val_loss: 2.1082 - val_accuracy: 0.5231
# Epoch 4/12
# 469/469 [==============================] - 5s 10ms/step - loss: 2.0990 - accuracy: 0.3512 - val_loss: 2.0161 - val_accuracy: 0.6016
# Epoch 5/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.0080 - accuracy: 0.4185 - val_loss: 1.9023 - val_accuracy: 0.6621
# Epoch 6/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.9001 - accuracy: 0.4678 - val_loss: 1.7649 - val_accuracy: 0.6984
# Epoch 7/12
# 469/469 [==============================] - 3s 7ms/step - loss: 1.7791 - accuracy: 0.5074 - val_loss: 1.6101 - val_accuracy: 0.7279
# Epoch 8/12
# 469/469 [==============================] - 3s 7ms/step - loss: 1.6509 - accuracy: 0.5422 - val_loss: 1.4491 - val_accuracy: 0.7512
# Epoch 9/12
# 469/469 [==============================] - 4s 7ms/step - loss: 1.5216 - accuracy: 0.5707 - val_loss: 1.2937 - val_accuracy: 0.7742
# Epoch 10/12
# 469/469 [==============================] - 3s 7ms/step - loss: 1.4066 - accuracy: 0.5963 - val_loss: 1.1555 - val_accuracy: 0.7912
# Epoch 11/12
# 469/469 [==============================] - 3s 7ms/step - loss: 1.2994 - accuracy: 0.6214 - val_loss: 1.0359 - val_accuracy: 0.8060
# Epoch 12/12
# 469/469 [==============================] - 3s 7ms/step - loss: 1.2098 - accuracy: 0.6391 - val_loss: 0.9367 - val_accuracy: 0.8170

# %%
score = model.evaluate(X_test, Y_test, verbose = 0)

print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.9366806745529175
# Test accuracy: 0.8169999718666077
