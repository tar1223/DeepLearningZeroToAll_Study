# %%
from keras.models import Sequential
from keras.layers import Activation
from keras.layers import Dense
from keras.utils import np_utils

import numpy as np
import os

# %%
# sample text
sample = "hihello"

char_set = list(set(sample)) # id -> char ['i', 'l', 'e', 'o', 'h']
char_dic = {w: i for i, w in enumerate(char_set)}

x_str = sample[:-1]
y_str = sample[1:]

data_dim = len(char_set)
timesteps = len(y_str)
num_classes = len(char_set)

print(x_str, y_str)
# Out:
# hihell ihello

# %%
x = [char_dic[c] for c in x_str] # char to index
y = [char_dic[c] for c in y_str] # char to index

# %%
# One-hot encoding
x = np_utils.to_categorical(x, num_classes = num_classes)
# reshape X to be [samples, time steps, features]
x = np.reshape(x, (-1, len(x), data_dim))
print(x.shape)
# Out:
# (1, 6, 5)

# %%
# One-hot encoding
y = np_utils.to_categorical(y, num_classes = num_classes)
# time steps
y = np.reshape(y, (-1, len(y), data_dim))
print(y.shape)
# Out:
# (1, 6, 5)

# %%
model = Sequential()
model.add(Dense(num_classes, input_shape = (timesteps, data_dim)))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6, 5)              30
#
#  activation (Activation)     (None, 6, 5)              0
#
# =================================================================
# Total params: 30
# Trainable params: 30
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %%
model.fit(x, y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 434ms/step - loss: 1.5420 - accuracy: 0.3333
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5372 - accuracy: 0.3333
# Epoch 3/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5337 - accuracy: 0.3333
# Epoch 4/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5309 - accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5283 - accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5260 - accuracy: 0.3333
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5238 - accuracy: 0.3333
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5218 - accuracy: 0.3333
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5198 - accuracy: 0.3333
# Epoch 10/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5179 - accuracy: 0.3333
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5161 - accuracy: 0.3333
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5143 - accuracy: 0.3333
# Epoch 13/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5126 - accuracy: 0.3333
# Epoch 14/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.5109 - accuracy: 0.3333
# Epoch 15/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.5092 - accuracy: 0.3333
# Epoch 16/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5076 - accuracy: 0.3333
# Epoch 17/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5060 - accuracy: 0.3333
# Epoch 18/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5044 - accuracy: 0.3333
# Epoch 19/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5028 - accuracy: 0.3333
# Epoch 20/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.5013 - accuracy: 0.3333
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4997 - accuracy: 0.3333
# Epoch 22/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4982 - accuracy: 0.3333
# Epoch 23/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.4967 - accuracy: 0.3333
# Epoch 24/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4952 - accuracy: 0.3333
# Epoch 25/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4937 - accuracy: 0.3333
# Epoch 26/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4922 - accuracy: 0.3333
# Epoch 27/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.4907 - accuracy: 0.3333
# Epoch 28/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4892 - accuracy: 0.3333
# Epoch 29/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4878 - accuracy: 0.3333
# Epoch 30/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4863 - accuracy: 0.3333
# Epoch 31/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4849 - accuracy: 0.3333
# Epoch 32/100
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4834 - accuracy: 0.3333
# Epoch 33/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4820 - accuracy: 0.3333
# Epoch 34/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4805 - accuracy: 0.3333
# Epoch 35/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4791 - accuracy: 0.3333
# Epoch 36/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.4777 - accuracy: 0.3333
# Epoch 37/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4763 - accuracy: 0.3333
# Epoch 38/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4748 - accuracy: 0.3333
# Epoch 39/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4734 - accuracy: 0.3333
# Epoch 40/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4720 - accuracy: 0.3333
# Epoch 41/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4706 - accuracy: 0.3333
# Epoch 42/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4692 - accuracy: 0.3333
# Epoch 43/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4678 - accuracy: 0.3333
# Epoch 44/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4664 - accuracy: 0.3333
# Epoch 45/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4650 - accuracy: 0.3333
# Epoch 46/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4636 - accuracy: 0.3333
# Epoch 47/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4622 - accuracy: 0.3333
# Epoch 48/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4608 - accuracy: 0.3333
# Epoch 49/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4594 - accuracy: 0.3333
# Epoch 50/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4580 - accuracy: 0.3333
# Epoch 51/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4566 - accuracy: 0.3333
# Epoch 52/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4553 - accuracy: 0.3333
# Epoch 53/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4539 - accuracy: 0.3333
# Epoch 54/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.4525 - accuracy: 0.3333
# Epoch 55/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4511 - accuracy: 0.3333
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4498 - accuracy: 0.3333
# Epoch 57/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4484 - accuracy: 0.3333
# Epoch 58/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4470 - accuracy: 0.3333
# Epoch 59/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.4457 - accuracy: 0.3333
# Epoch 60/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.4443 - accuracy: 0.3333
# Epoch 61/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4430 - accuracy: 0.3333
# Epoch 62/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4416 - accuracy: 0.3333
# Epoch 63/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4402 - accuracy: 0.3333
# Epoch 64/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.4389 - accuracy: 0.3333
# Epoch 65/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4375 - accuracy: 0.3333
# Epoch 66/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4362 - accuracy: 0.3333
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4348 - accuracy: 0.3333
# Epoch 68/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4335 - accuracy: 0.3333
# Epoch 69/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4322 - accuracy: 0.3333
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4308 - accuracy: 0.3333
# Epoch 71/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4295 - accuracy: 0.3333
# Epoch 72/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4281 - accuracy: 0.3333
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4268 - accuracy: 0.3333
# Epoch 74/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4255 - accuracy: 0.3333
# Epoch 75/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4241 - accuracy: 0.3333
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4228 - accuracy: 0.3333
# Epoch 77/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4215 - accuracy: 0.3333
# Epoch 78/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4202 - accuracy: 0.3333
# Epoch 79/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4188 - accuracy: 0.3333
# Epoch 80/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4175 - accuracy: 0.3333
# Epoch 81/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4162 - accuracy: 0.3333
# Epoch 82/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4149 - accuracy: 0.3333
# Epoch 83/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4136 - accuracy: 0.3333
# Epoch 84/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4123 - accuracy: 0.3333
# Epoch 85/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4110 - accuracy: 0.3333
# Epoch 86/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4097 - accuracy: 0.3333
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4084 - accuracy: 0.3333
# Epoch 88/100
# 1/1 [==============================] - 0s 28ms/step - loss: 1.4070 - accuracy: 0.3333
# Epoch 89/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4057 - accuracy: 0.3333
# Epoch 90/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4044 - accuracy: 0.3333
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4032 - accuracy: 0.3333
# Epoch 92/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4019 - accuracy: 0.3333
# Epoch 93/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4006 - accuracy: 0.3333
# Epoch 94/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3993 - accuracy: 0.3333
# Epoch 95/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3980 - accuracy: 0.3333
# Epoch 96/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3967 - accuracy: 0.3333
# Epoch 97/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3954 - accuracy: 0.3333
# Epoch 98/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3941 - accuracy: 0.3333
# Epoch 99/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3929 - accuracy: 0.3333
# Epoch 100/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3916 - accuracy: 0.3333

# %%
predictions = model.predict(x, verbose = 0)

for i, prediction in enumerate(predictions):
  x_index = np.argmax(x[i], axis = 1)
  x_str = [char_set[j] for j in x_index]
  print(x_index, ''.join(x_str))

  index = np.argmax(prediction, axis = 1)
  result = [char_set[j] for j in index]
  print(index, ''.join(result))
# Out:
# [1 2 1 4 0 0] hihell
# [4 0 4 0 1 1] elelhh
