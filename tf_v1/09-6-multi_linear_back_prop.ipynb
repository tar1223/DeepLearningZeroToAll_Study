# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

# %%
tf.set_random_seed(777) # reproducibility

# %%
# tf Graph Input
x_data = [[73., 80., 75.],
          [93., 88., 93.],
          [89., 91., 90.],
          [96., 98., 100.],
          [73., 66., 70.]]
y_data = [[152.],
          [185.],
          [180.],
          [196.],
          [142.]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape = [None, 3])
Y = tf.placeholder(tf.float32, shape = [None, 1])

# %%
# Set wrong model weights
W = tf.Variable(tf.truncated_normal([3, 1]))
b = tf.Variable(5.)

# %%
# Forward prop
hypothesis = tf.matmul(X, W) + b

# %%
print(hypothesis.shape, Y.shape)
# Out:
# (?, 1) (?, 1)

# %%
# diff
assert hypothesis.shape.as_list() == Y.shape.as_list()
diff = (hypothesis - Y)

# %%
# Back prop (chain rule)
d_l1 = diff
d_b = d_l1
d_w = tf.matmul(tf.transpose(X), d_l1)

# %%
print(X, d_l1, d_w)
# Out:
# Tensor("Placeholder:0", shape=(?, 3), dtype=float32) Tensor("sub:0", shape=(?, 1), dtype=float32) Tensor("MatMul_1:0", shape=(3, 1), dtype=float32)

# %%
# Updating network using gradients
learning_rate = 1e-6
step = [
        tf.assign(W, W - learning_rate * d_w),
        tf.assign(b, b - learning_rate * tf.reduce_mean(d_b)),
]

# %%
# Running and testing the training process
RMSE = tf.reduce_mean(tf.square((Y - hypothesis)))

# %%
sess = tf.InteractiveSession()
init = tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(10000):
  print(i, sess.run([step, RMSE], feed_dict = {X: x_data, Y: y_data}))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#        [ 1.0525234],
#        [-0.5439065]], dtype=float32), 5.001305], 4.411358]
# 8334 [[array([[ 1.4586065 ],
#        [ 1.0525056 ],
#        [-0.54389566]], dtype=float32), 5.001305], 4.41118]
# 8335 [[array([[ 1.4586133],
#        [ 1.0524879],
#        [-0.5438849]], dtype=float32), 5.001305], 4.4109836]
# 8336 [[array([[ 1.4586201],
#        [ 1.0524701],
#        [-0.543874 ]], dtype=float32), 5.001305], 4.4107814]
# 8337 [[array([[ 1.4586269 ],
#        [ 1.0524523 ],
#        [-0.54386324]], dtype=float32), 5.001305], 4.410568]
# 8338 [[array([[ 1.4586337 ],
#        [ 1.0524346 ],
#        [-0.54385245]], dtype=float32), 5.001305], 4.4103994]
# 8339 [[array([[ 1.4586405],
#        [ 1.0524168],
#        [-0.5438416]], dtype=float32), 5.001305], 4.410193]
# 8340 [[array([[ 1.4586473],
#        [ 1.052399 ],
#        [-0.5438308]], dtype=float32), 5.001305], 4.4100423]
# 8341 [[array([[ 1.458654  ],
#        [ 1.0523813 ],
#        [-0.54381996]], dtype=float32), 5.001305], 4.409841]
# 8342 [[array([[ 1.4586608],
#        [ 1.0523635],
#        [-0.5438091]], dtype=float32), 5.001305], 4.4096117]
# 8343 [[array([[ 1.4586676],
#        [ 1.0523458],
#        [-0.5437983]], dtype=float32), 5.001305], 4.409444]
# 8344 [[array([[ 1.4586744 ],
#        [ 1.052328  ],
#        [-0.54378754]], dtype=float32), 5.001305], 4.4092383]
# 8345 [[array([[ 1.4586812],
#        [ 1.0523102],
#        [-0.5437767]], dtype=float32), 5.001305], 4.4090376]
# 8346 [[array([[ 1.458688 ],
#        [ 1.0522925],
#        [-0.5437659]], dtype=float32), 5.001305], 4.4088736]
# 8347 [[array([[ 1.4586948],
#        [ 1.0522747],
#        [-0.5437551]], dtype=float32), 5.001305], 4.4086733]
# 8348 [[array([[ 1.4587016 ],
#        [ 1.052257  ],
#        [-0.54374427]], dtype=float32), 5.001305], 4.4084954]
# 8349 [[array([[ 1.4587084],
#        [ 1.0522392],
#        [-0.5437335]], dtype=float32), 5.001305], 4.4082804]
# 8350 [[array([[ 1.4587152],
#        [ 1.0522214],
#        [-0.5437226]], dtype=float32), 5.001305], 4.408088]
# 8351 [[array([[ 1.458722 ],
#        [ 1.0522037],
#        [-0.5437118]], dtype=float32), 5.001305], 4.4079323]
# 8352 [[array([[ 1.4587288 ],
#        [ 1.0521859 ],
#        [-0.54370093]], dtype=float32), 5.001305], 4.407741]
# 8353 [[array([[ 1.4587356 ],
#        [ 1.0521681 ],
#        [-0.54369015]], dtype=float32), 5.001305], 4.407518]
# 8354 [[array([[ 1.4587424 ],
#        [ 1.0521504 ],
#        [-0.54367936]], dtype=float32), 5.001305], 4.4073496]
# 8355 [[array([[ 1.4587492 ],
#        [ 1.0521326 ],
#        [-0.54366857]], dtype=float32), 5.001305], 4.4071574]
# 8356 [[array([[ 1.458756 ],
#        [ 1.0521148],
#        [-0.5436577]], dtype=float32), 5.001305], 4.4069514]
# 8357 [[array([[ 1.4587628 ],
#        [ 1.0520971 ],
#        [-0.54364693]], dtype=float32), 5.001305], 4.406764]
# 8358 [[array([[ 1.4587696],
#        [ 1.0520793],
#        [-0.5436361]], dtype=float32), 5.001305], 4.40658]
# 8359 [[array([[ 1.4587764],
#        [ 1.0520616],
#        [-0.5436253]], dtype=float32), 5.001305], 4.4063807]
# 8360 [[array([[ 1.4587831],
#        [ 1.0520438],
#        [-0.5436145]], dtype=float32), 5.001305], 4.4062214]
# 8361 [[array([[ 1.45879   ],
#        [ 1.052026  ],
#        [-0.54360366]], dtype=float32), 5.001305], 4.406007]
# 8362 [[array([[ 1.4587967],
#        [ 1.0520083],
#        [-0.5435928]], dtype=float32), 5.001305], 4.4058022]
# 8363 [[array([[ 1.4588035],
#        [ 1.0519905],
#        [-0.543582 ]], dtype=float32), 5.001305], 4.405652]
# 8364 [[array([[ 1.4588103 ],
#        [ 1.0519727 ],
#        [-0.54357123]], dtype=float32), 5.001305], 4.4054556]
# 8365 [[array([[ 1.4588171],
#        [ 1.051955 ],
#        [-0.5435604]], dtype=float32), 5.001305], 4.405236]
# 8366 [[array([[ 1.4588239],
#        [ 1.0519372],
#        [-0.5435496]], dtype=float32), 5.001305], 4.4050436]
# 8367 [[array([[ 1.4588307 ],
#        [ 1.0519195 ],
#        [-0.54353875]], dtype=float32), 5.001305], 4.404866]
# 8368 [[array([[ 1.4588375],
#        [ 1.0519017],
#        [-0.5435279]], dtype=float32), 5.001305], 4.404676]
# 8369 [[array([[ 1.4588442],
#        [ 1.0518839],
#        [-0.5435171]], dtype=float32), 5.001305], 4.4044743]
# 8370 [[array([[ 1.458851  ],
#        [ 1.0518662 ],
#        [-0.54350626]], dtype=float32), 5.001305], 4.4042954]
# 8371 [[array([[ 1.4588578],
#        [ 1.0518484],
#        [-0.5434954]], dtype=float32), 5.001305], 4.4040956]
# 8372 [[array([[ 1.4588646 ],
#        [ 1.0518306 ],
#        [-0.54348457]], dtype=float32), 5.001305], 4.403923]
# 8373 [[array([[ 1.4588712],
#        [ 1.0518129],
#        [-0.5434738]], dtype=float32), 5.001305], 4.4037175]
# 8374 [[array([[ 1.458878  ],
#        [ 1.0517951 ],
#        [-0.54346293]], dtype=float32), 5.001305], 4.4035287]
# 8375 [[array([[ 1.4588848],
#        [ 1.0517774],
#        [-0.5434521]], dtype=float32), 5.001305], 4.4033394]
# 8376 [[array([[ 1.4588916 ],
#        [ 1.0517596 ],
#        [-0.54344124]], dtype=float32), 5.001305], 4.4031305]
# 8377 [[array([[ 1.4588984],
#        [ 1.051742 ],
#        [-0.5434304]], dtype=float32), 5.001305], 4.4029694]
# 8378 [[array([[ 1.4589051],
#        [ 1.0517242],
#        [-0.5434196]], dtype=float32), 5.001305], 4.40276]
# 8379 [[array([[ 1.4589118 ],
#        [ 1.0517066 ],
#        [-0.54340875]], dtype=float32), 5.001305], 4.4025793]
# 8380 [[array([[ 1.4589185],
#        [ 1.0516889],
#        [-0.5433979]], dtype=float32), 5.001305], 4.402382]
# 8381 [[array([[ 1.4589251 ],
#        [ 1.0516713 ],
#        [-0.54338706]], dtype=float32), 5.001305], 4.402185]
# 8382 [[array([[ 1.4589318 ],
#        [ 1.0516536 ],
#        [-0.54337627]], dtype=float32), 5.001305], 4.402004]
# 8383 [[array([[ 1.4589385],
#        [ 1.051636 ],
#        [-0.5433654]], dtype=float32), 5.001305], 4.401808]
# 8384 [[array([[ 1.4589452],
#        [ 1.0516183],
#        [-0.5433546]], dtype=float32), 5.001305], 4.4016256]
# 8385 [[array([[ 1.4589518],
#        [ 1.0516007],
#        [-0.5433437]], dtype=float32), 5.001305], 4.401438]
# 8386 [[array([[ 1.4589585 ],
#        [ 1.051583  ],
#        [-0.54333293]], dtype=float32), 5.001305], 4.401229]
# 8387 [[array([[ 1.4589652 ],
#        [ 1.0515654 ],
#        [-0.54332215]], dtype=float32), 5.001305], 4.4010606]
# 8388 [[array([[ 1.4589719 ],
#        [ 1.0515478 ],
#        [-0.54331136]], dtype=float32), 5.001305], 4.4008756]
# 8389 [[array([[ 1.4589785],
#        [ 1.0515301],
#        [-0.5433005]], dtype=float32), 5.001305], 4.400649]
# 8390 [[array([[ 1.4589852 ],
#        [ 1.0515125 ],
#        [-0.54328966]], dtype=float32), 5.001305], 4.400464]
# 8391 [[array([[ 1.4589919],
#        [ 1.0514948],
#        [-0.5432789]], dtype=float32), 5.001305], 4.400314]
# 8392 [[array([[ 1.4589986],
#        [ 1.0514772],
#        [-0.5432681]], dtype=float32), 5.001305], 4.4001093]
# 8393 [[array([[ 1.4590052],
#        [ 1.0514596],
#        [-0.5432573]], dtype=float32), 5.001305], 4.3999157]
# 8394 [[array([[ 1.4590119 ],
#        [ 1.0514419 ],
#        [-0.54324645]], dtype=float32), 5.001305], 4.3997393]
# 8395 [[array([[ 1.4590186],
#        [ 1.0514243],
#        [-0.5432356]], dtype=float32), 5.001305], 4.399535]
# 8396 [[array([[ 1.4590253],
#        [ 1.0514066],
#        [-0.5432248]], dtype=float32), 5.001305], 4.399339]
# 8397 [[array([[ 1.4590319 ],
#        [ 1.051389  ],
#        [-0.54321396]], dtype=float32), 5.001305], 4.3991475]
# 8398 [[array([[ 1.4590386],
#        [ 1.0513713],
#        [-0.5432032]], dtype=float32), 5.001305], 4.3989735]
# 8399 [[array([[ 1.4590453],
#        [ 1.0513537],
#        [-0.5431924]], dtype=float32), 5.001305], 4.3987646]
# 8400 [[array([[ 1.459052  ],
#        [ 1.051336  ],
#        [-0.54318154]], dtype=float32), 5.001305], 4.398606]
# 8401 [[array([[ 1.4590586],
#        [ 1.0513184],
#        [-0.5431707]], dtype=float32), 5.001305], 4.398401]
# 8402 [[array([[ 1.4590653],
#        [ 1.0513008],
#        [-0.5431599]], dtype=float32), 5.001305], 4.398196]
# 8403 [[array([[ 1.459072  ],
#        [ 1.0512831 ],
#        [-0.54314905]], dtype=float32), 5.001305], 4.3980136]
# 8404 [[array([[ 1.4590787 ],
#        [ 1.0512655 ],
#        [-0.54313827]], dtype=float32), 5.001305], 4.397846]
# 8405 [[array([[ 1.4590853],
#        [ 1.0512478],
#        [-0.5431275]], dtype=float32), 5.001305], 4.3976297]
# 8406 [[array([[ 1.459092 ],
#        [ 1.0512302],
#        [-0.5431167]], dtype=float32), 5.001305], 4.3974457]
# 8407 [[array([[ 1.4590987 ],
#        [ 1.0512125 ],
#        [-0.54310584]], dtype=float32), 5.001305], 4.3972797]
# 8408 [[array([[ 1.4591054],
#        [ 1.0511949],
#        [-0.543095 ]], dtype=float32), 5.001305], 4.397067]
# 8409 [[array([[ 1.459112 ],
#        [ 1.0511773],
#        [-0.5430842]], dtype=float32), 5.001305], 4.396867]
# 8410 [[array([[ 1.4591187 ],
#        [ 1.0511596 ],
#        [-0.54307336]], dtype=float32), 5.001305], 4.3967214]
# 8411 [[array([[ 1.4591254],
#        [ 1.051142 ],
#        [-0.5430625]], dtype=float32), 5.001305], 4.3965173]
# 8412 [[array([[ 1.4591321],
#        [ 1.0511243],
#        [-0.5430517]], dtype=float32), 5.001305], 4.3962984]
# 8413 [[array([[ 1.4591388],
#        [ 1.0511067],
#        [-0.5430409]], dtype=float32), 5.001305], 4.3961196]
# 8414 [[array([[ 1.4591454],
#        [ 1.051089 ],
#        [-0.5430301]], dtype=float32), 5.001305], 4.395956]
# 8415 [[array([[ 1.4591521],
#        [ 1.0510714],
#        [-0.5430193]], dtype=float32), 5.001305], 4.395747]
# 8416 [[array([[ 1.4591588],
#        [ 1.0510538],
#        [-0.5430085]], dtype=float32), 5.001305], 4.395565]
# 8417 [[array([[ 1.4591655 ],
#        [ 1.0510361 ],
#        [-0.54299766]], dtype=float32), 5.001305], 4.3953743]
# 8418 [[array([[ 1.4591721 ],
#        [ 1.0510185 ],
#        [-0.54298687]], dtype=float32), 5.001305], 4.3951635]
# 8419 [[array([[ 1.4591788],
#        [ 1.0510008],
#        [-0.542976 ]], dtype=float32), 5.001305], 4.3949876]
# 8420 [[array([[ 1.4591855],
#        [ 1.0509832],
#        [-0.5429652]], dtype=float32), 5.001305], 4.3948026]
# 8421 [[array([[ 1.4591922],
#        [ 1.0509655],
#        [-0.5429544]], dtype=float32), 5.001305], 4.3946037]
# 8422 [[array([[ 1.4591988],
#        [ 1.0509479],
#        [-0.5429436]], dtype=float32), 5.001305], 4.394419]
# 8423 [[array([[ 1.4592055 ],
#        [ 1.0509303 ],
#        [-0.54293275]], dtype=float32), 5.001305], 4.3942504]
# 8424 [[array([[ 1.4592122],
#        [ 1.0509126],
#        [-0.5429219]], dtype=float32), 5.001305], 4.3940516]
# 8425 [[array([[ 1.4592189],
#        [ 1.050895 ],
#        [-0.5429111]], dtype=float32), 5.001305], 4.3938413]
# 8426 [[array([[ 1.4592255 ],
#        [ 1.0508773 ],
#        [-0.54290026]], dtype=float32), 5.001305], 4.393665]
# 8427 [[array([[ 1.4592322],
#        [ 1.0508597],
#        [-0.5428895]], dtype=float32), 5.001305], 4.3934784]
# 8428 [[array([[ 1.4592389],
#        [ 1.050842 ],
#        [-0.5428787]], dtype=float32), 5.001305], 4.3932977]
# 8429 [[array([[ 1.4592456 ],
#        [ 1.0508244 ],
#        [-0.54286784]], dtype=float32), 5.001305], 4.393095]
# 8430 [[array([[ 1.4592522],
#        [ 1.0508068],
#        [-0.542857 ]], dtype=float32), 5.001305], 4.3929043]
# 8431 [[array([[ 1.4592589],
#        [ 1.0507891],
#        [-0.5428462]], dtype=float32), 5.001305], 4.3927054]
# 8432 [[array([[ 1.4592656],
#        [ 1.0507715],
#        [-0.5428354]], dtype=float32), 5.001305], 4.3925333]
# 8433 [[array([[ 1.4592723 ],
#        [ 1.0507538 ],
#        [-0.54282457]], dtype=float32), 5.001305], 4.3923187]
# 8434 [[array([[ 1.459279 ],
#        [ 1.0507362],
#        [-0.5428138]], dtype=float32), 5.001305], 4.39214]
# 8435 [[array([[ 1.4592856],
#        [ 1.0507185],
#        [-0.542803 ]], dtype=float32), 5.001305], 4.3919497]
# 8436 [[array([[ 1.4592923 ],
#        [ 1.0507009 ],
#        [-0.54279214]], dtype=float32), 5.001305], 4.391787]
# 8437 [[array([[ 1.459299 ],
#        [ 1.0506833],
#        [-0.5427813]], dtype=float32), 5.001305], 4.3915873]
# 8438 [[array([[ 1.4593056],
#        [ 1.0506656],
#        [-0.5427705]], dtype=float32), 5.001305], 4.391375]
# 8439 [[array([[ 1.4593123 ],
#        [ 1.050648  ],
#        [-0.54275966]], dtype=float32), 5.001305], 4.3912096]
# 8440 [[array([[ 1.459319 ],
#        [ 1.0506303],
#        [-0.5427488]], dtype=float32), 5.001305], 4.3910284]
# 8441 [[array([[ 1.4593257],
#        [ 1.0506127],
#        [-0.542738 ]], dtype=float32), 5.001305], 4.3908286]
# 8442 [[array([[ 1.4593323 ],
#        [ 1.050595  ],
#        [-0.54272723]], dtype=float32), 5.001305], 4.390652]
# 8443 [[array([[ 1.459339  ],
#        [ 1.0505774 ],
#        [-0.54271644]], dtype=float32), 5.001305], 4.390448]
# 8444 [[array([[ 1.4593457],
#        [ 1.0505598],
#        [-0.5427056]], dtype=float32), 5.001305], 4.390242]
# 8445 [[array([[ 1.4593524 ],
#        [ 1.0505421 ],
#        [-0.54269475]], dtype=float32), 5.001305], 4.390042]
# 8446 [[array([[ 1.459359  ],
#        [ 1.0505245 ],
#        [-0.54268396]], dtype=float32), 5.001305], 4.3898787]
# 8447 [[array([[ 1.4593657],
#        [ 1.0505068],
#        [-0.5426732]], dtype=float32), 5.001305], 4.3896885]
# 8448 [[array([[ 1.4593724],
#        [ 1.0504892],
#        [-0.5426623]], dtype=float32), 5.001305], 4.389501]
# 8449 [[array([[ 1.4593791],
#        [ 1.0504715],
#        [-0.5426515]], dtype=float32), 5.001305], 4.3892975]
# 8450 [[array([[ 1.4593858],
#        [ 1.0504539],
#        [-0.5426407]], dtype=float32), 5.001305], 4.3891163]
# 8451 [[array([[ 1.4593924],
#        [ 1.0504363],
#        [-0.5426299]], dtype=float32), 5.001305], 4.3889213]
# 8452 [[array([[ 1.4593991 ],
#        [ 1.0504186 ],
#        [-0.54261905]], dtype=float32), 5.001305], 4.3887625]
# 8453 [[array([[ 1.4594058 ],
#        [ 1.050401  ],
#        [-0.54260826]], dtype=float32), 5.001305], 4.3885527]
# 8454 [[array([[ 1.4594125],
#        [ 1.0503833],
#        [-0.5425974]], dtype=float32), 5.001305], 4.388358]
# 8455 [[array([[ 1.4594191],
#        [ 1.0503657],
#        [-0.5425866]], dtype=float32), 5.001305], 4.388191]
# 8456 [[array([[ 1.4594258],
#        [ 1.050348 ],
#        [-0.5425758]], dtype=float32), 5.001305], 4.3880014]
# 8457 [[array([[ 1.4594325],
#        [ 1.0503304],
#        [-0.542565 ]], dtype=float32), 5.001305], 4.387822]
# 8458 [[array([[ 1.4594392 ],
#        [ 1.0503128 ],
#        [-0.54255414]], dtype=float32), 5.001305], 4.3876224]
# 8459 [[array([[ 1.4594458],
#        [ 1.0502951],
#        [-0.5425433]], dtype=float32), 5.001305], 4.387418]
# 8460 [[array([[ 1.4594525],
#        [ 1.0502775],
#        [-0.5425325]], dtype=float32), 5.001305], 4.3872375]
# 8461 [[array([[ 1.4594592 ],
#        [ 1.0502598 ],
#        [-0.54252166]], dtype=float32), 5.001305], 4.3870325]
# 8462 [[array([[ 1.4594659 ],
#        [ 1.0502422 ],
#        [-0.54251087]], dtype=float32), 5.001305], 4.386859]
# 8463 [[array([[ 1.4594725],
#        [ 1.0502245],
#        [-0.5425001]], dtype=float32), 5.001305], 4.3866606]
# 8464 [[array([[ 1.4594792 ],
#        [ 1.0502069 ],
#        [-0.54248923]], dtype=float32), 5.001305], 4.386507]
# 8465 [[array([[ 1.4594859 ],
#        [ 1.0501893 ],
#        [-0.54247844]], dtype=float32), 5.001305], 4.3862753]
# 8466 [[array([[ 1.4594926],
#        [ 1.0501716],
#        [-0.5424676]], dtype=float32), 5.001305], 4.3861065]
# 8467 [[array([[ 1.4594992 ],
#        [ 1.050154  ],
#        [-0.54245675]], dtype=float32), 5.001305], 4.3859167]
# 8468 [[array([[ 1.4595059 ],
#        [ 1.0501363 ],
#        [-0.54244596]], dtype=float32), 5.001305], 4.3857355]
# 8469 [[array([[ 1.4595126 ],
#        [ 1.0501187 ],
#        [-0.54243517]], dtype=float32), 5.001305], 4.385545]
# 8470 [[array([[ 1.4595193],
#        [ 1.050101 ],
#        [-0.5424244]], dtype=float32), 5.001305], 4.38535]
# 8471 [[array([[ 1.459526  ],
#        [ 1.0500834 ],
#        [-0.54241353]], dtype=float32), 5.001305], 4.385168]
# 8472 [[array([[ 1.4595326 ],
#        [ 1.0500658 ],
#        [-0.54240274]], dtype=float32), 5.001305], 4.3849697]
# 8473 [[array([[ 1.4595393],
#        [ 1.0500482],
#        [-0.5423919]], dtype=float32), 5.001305], 4.3847876]
# 8474 [[array([[ 1.459546 ],
#        [ 1.0500306],
#        [-0.5423811]], dtype=float32), 5.001305], 4.3845873]
# 8475 [[array([[ 1.4595526],
#        [ 1.050013 ],
#        [-0.5423703]], dtype=float32), 5.001305], 4.3843894]
# 8476 [[array([[ 1.4595593 ],
#        [ 1.0499954 ],
#        [-0.54235953]], dtype=float32), 5.001305], 4.3841944]
# 8477 [[array([[ 1.459566  ],
#        [ 1.0499779 ],
#        [-0.54234874]], dtype=float32), 5.001305], 4.384]
# 8478 [[array([[ 1.4595727 ],
#        [ 1.0499603 ],
#        [-0.54233795]], dtype=float32), 5.001305], 4.38384]
# 8479 [[array([[ 1.4595793 ],
#        [ 1.0499427 ],
#        [-0.54232717]], dtype=float32), 5.001305], 4.3836374]
# 8480 [[array([[ 1.459586 ],
#        [ 1.0499251],
#        [-0.5423164]], dtype=float32), 5.001305], 4.383465]
# 8481 [[array([[ 1.4595927],
#        [ 1.0499076],
#        [-0.5423056]], dtype=float32), 5.001305], 4.3833055]
# 8482 [[array([[ 1.4595994],
#        [ 1.0498899],
#        [-0.5422948]], dtype=float32), 5.001305], 4.383092]
# 8483 [[array([[ 1.459606 ],
#        [ 1.0498724],
#        [-0.542284 ]], dtype=float32), 5.001305], 4.382898]
# 8484 [[array([[ 1.4596127],
#        [ 1.0498548],
#        [-0.5422732]], dtype=float32), 5.001305], 4.3827085]
# 8485 [[array([[ 1.4596194 ],
#        [ 1.0498372 ],
#        [-0.54226243]], dtype=float32), 5.001305], 4.382514]
# 8486 [[array([[ 1.4596261 ],
#        [ 1.0498196 ],
#        [-0.54225165]], dtype=float32), 5.001305], 4.3823457]
# 8487 [[array([[ 1.4596328 ],
#        [ 1.049802  ],
#        [-0.54224086]], dtype=float32), 5.001305], 4.382142]
# 8488 [[array([[ 1.4596394 ],
#        [ 1.0497844 ],
#        [-0.54223007]], dtype=float32), 5.001305], 4.3819876]
# 8489 [[array([[ 1.4596461],
#        [ 1.0497669],
#        [-0.5422193]], dtype=float32), 5.001305], 4.3817935]
# 8490 [[array([[ 1.4596528],
#        [ 1.0497493],
#        [-0.5422085]], dtype=float32), 5.001305], 4.3816094]
# 8491 [[array([[ 1.4596595],
#        [ 1.0497317],
#        [-0.5421977]], dtype=float32), 5.001305], 4.381399]
# 8492 [[array([[ 1.4596661],
#        [ 1.0497142],
#        [-0.5421869]], dtype=float32), 5.001305], 4.3812237]
# 8493 [[array([[ 1.4596728],
#        [ 1.0496967],
#        [-0.5421761]], dtype=float32), 5.001305], 4.3810096]
# 8494 [[array([[ 1.4596795 ],
#        [ 1.049679  ],
#        [-0.54216534]], dtype=float32), 5.001305], 4.3808203]
# 8495 [[array([[ 1.4596862 ],
#        [ 1.0496614 ],
#        [-0.54215455]], dtype=float32), 5.001305], 4.3806534]
# 8496 [[array([[ 1.4596928 ],
#        [ 1.0496439 ],
#        [-0.54214376]], dtype=float32), 5.001305], 4.380444]
# 8497 [[array([[ 1.4596995],
#        [ 1.0496262],
#        [-0.542133 ]], dtype=float32), 5.001305], 4.3802595]
# 8498 [[array([[ 1.4597062],
#        [ 1.0496086],
#        [-0.5421222]], dtype=float32), 5.001305], 4.380088]
# 8499 [[array([[ 1.4597129],
#        [ 1.0495911],
#        [-0.5421114]], dtype=float32), 5.001305], 4.3798885]
# 8500 [[array([[ 1.4597195],
#        [ 1.0495735],
#        [-0.5421006]], dtype=float32), 5.001305], 4.3797026]
# 8501 [[array([[ 1.4597262],
#        [ 1.049556 ],
#        [-0.5420898]], dtype=float32), 5.001305], 4.3795214]
# 8502 [[array([[ 1.4597329 ],
#        [ 1.0495384 ],
#        [-0.54207903]], dtype=float32), 5.001305], 4.3793225]
# 8503 [[array([[ 1.4597396 ],
#        [ 1.0495207 ],
#        [-0.54206824]], dtype=float32), 5.001305], 4.379142]
# 8504 [[array([[ 1.4597462 ],
#        [ 1.0495032 ],
#        [-0.54205745]], dtype=float32), 5.001305], 4.378957]
# 8505 [[array([[ 1.4597529 ],
#        [ 1.0494857 ],
#        [-0.54204667]], dtype=float32), 5.001305], 4.378776]
# 8506 [[array([[ 1.4597596],
#        [ 1.049468 ],
#        [-0.5420359]], dtype=float32), 5.001305], 4.378587]
# 8507 [[array([[ 1.4597663],
#        [ 1.0494504],
#        [-0.5420251]], dtype=float32), 5.001305], 4.378367]
# 8508 [[array([[ 1.459773 ],
#        [ 1.0494329],
#        [-0.5420143]], dtype=float32), 5.001305], 4.378192]
# 8509 [[array([[ 1.4597796],
#        [ 1.0494153],
#        [-0.5420035]], dtype=float32), 5.001305], 4.3780117]
# 8510 [[array([[ 1.4597863],
#        [ 1.0493978],
#        [-0.5419927]], dtype=float32), 5.001305], 4.377802]
# 8511 [[array([[ 1.4597929 ],
#        [ 1.0493802 ],
#        [-0.54198194]], dtype=float32), 5.001305], 4.377623]
# 8512 [[array([[ 1.4597995 ],
#        [ 1.0493627 ],
#        [-0.54197115]], dtype=float32), 5.001305], 4.377436]
# 8513 [[array([[ 1.4598061 ],
#        [ 1.0493451 ],
#        [-0.54196036]], dtype=float32), 5.001305], 4.377266]
# 8514 [[array([[ 1.4598126 ],
#        [ 1.0493276 ],
#        [-0.54194957]], dtype=float32), 5.001305], 4.3770514]
# 8515 [[array([[ 1.4598192],
#        [ 1.0493101],
#        [-0.5419388]], dtype=float32), 5.001305], 4.3768706]
# 8516 [[array([[ 1.4598258],
#        [ 1.0492926],
#        [-0.541928 ]], dtype=float32), 5.001305], 4.376706]
# 8517 [[array([[ 1.4598323],
#        [ 1.049275 ],
#        [-0.5419172]], dtype=float32), 5.001305], 4.376523]
# 8518 [[array([[ 1.4598389],
#        [ 1.0492575],
#        [-0.5419064]], dtype=float32), 5.001305], 4.3763494]
# 8519 [[array([[ 1.4598454],
#        [ 1.04924  ],
#        [-0.5418956]], dtype=float32), 5.001305], 4.3761415]
# 8520 [[array([[ 1.459852  ],
#        [ 1.0492225 ],
#        [-0.54188484]], dtype=float32), 5.001305], 4.3759646]
# 8521 [[array([[ 1.4598587 ],
#        [ 1.049205  ],
#        [-0.54187405]], dtype=float32), 5.001305], 4.37576]
# 8522 [[array([[ 1.4598652 ],
#        [ 1.0491874 ],
#        [-0.54186326]], dtype=float32), 5.001305], 4.37558]
# 8523 [[array([[ 1.4598718],
#        [ 1.0491699],
#        [-0.5418525]], dtype=float32), 5.001305], 4.3753805]
# 8524 [[array([[ 1.4598783],
#        [ 1.0491524],
#        [-0.5418417]], dtype=float32), 5.001305], 4.375187]
# 8525 [[array([[ 1.4598849],
#        [ 1.0491349],
#        [-0.5418309]], dtype=float32), 5.001305], 4.3750563]
# 8526 [[array([[ 1.4598914],
#        [ 1.0491173],
#        [-0.5418201]], dtype=float32), 5.001305], 4.3748198]
# 8527 [[array([[ 1.459898 ],
#        [ 1.0490998],
#        [-0.5418093]], dtype=float32), 5.001305], 4.374653]
# 8528 [[array([[ 1.4599046 ],
#        [ 1.0490823 ],
#        [-0.54179853]], dtype=float32), 5.001305], 4.374459]
# 8529 [[array([[ 1.4599112 ],
#        [ 1.0490648 ],
#        [-0.54178774]], dtype=float32), 5.001305], 4.374268]
# 8530 [[array([[ 1.4599178 ],
#        [ 1.0490472 ],
#        [-0.54177696]], dtype=float32), 5.001305], 4.374083]
# 8531 [[array([[ 1.4599243 ],
#        [ 1.0490297 ],
#        [-0.54176617]], dtype=float32), 5.001305], 4.3738785]
# 8532 [[array([[ 1.4599309],
#        [ 1.0490122],
#        [-0.5417554]], dtype=float32), 5.001305], 4.3736987]
# 8533 [[array([[ 1.4599375],
#        [ 1.0489947],
#        [-0.5417446]], dtype=float32), 5.001305], 4.3735547]
# 8534 [[array([[ 1.459944 ],
#        [ 1.0489771],
#        [-0.5417338]], dtype=float32), 5.001305], 4.3733315]
# 8535 [[array([[ 1.4599506],
#        [ 1.0489596],
#        [-0.541723 ]], dtype=float32), 5.001305], 4.3731427]
# 8536 [[array([[ 1.4599571],
#        [ 1.0489421],
#        [-0.5417122]], dtype=float32), 5.001305], 4.372971]
# 8537 [[array([[ 1.4599637 ],
#        [ 1.0489246 ],
#        [-0.54170144]], dtype=float32), 5.001305], 4.3727894]
# 8538 [[array([[ 1.4599704 ],
#        [ 1.048907  ],
#        [-0.54169065]], dtype=float32), 5.001305], 4.372604]
# 8539 [[array([[ 1.4599769 ],
#        [ 1.0488895 ],
#        [-0.54167986]], dtype=float32), 5.001305], 4.372415]
# 8540 [[array([[ 1.4599835],
#        [ 1.048872 ],
#        [-0.5416691]], dtype=float32), 5.001305], 4.372211]
# 8541 [[array([[ 1.45999  ],
#        [ 1.0488545],
#        [-0.5416583]], dtype=float32), 5.001305], 4.372026]
# 8542 [[array([[ 1.4599966],
#        [ 1.048837 ],
#        [-0.5416475]], dtype=float32), 5.001305], 4.3718405]
# 8543 [[array([[ 1.4600031],
#        [ 1.0488194],
#        [-0.5416367]], dtype=float32), 5.001305], 4.3716555]
# 8544 [[array([[ 1.4600097],
#        [ 1.0488019],
#        [-0.5416259]], dtype=float32), 5.001305], 4.3714423]
# 8545 [[array([[ 1.4600163],
#        [ 1.0487844],
#        [-0.5416151]], dtype=float32), 5.001305], 4.371275]
# 8546 [[array([[ 1.4600229 ],
#        [ 1.0487669 ],
#        [-0.54160434]], dtype=float32), 5.001305], 4.371085]
# 8547 [[array([[ 1.4600295 ],
#        [ 1.0487493 ],
#        [-0.54159355]], dtype=float32), 5.001305], 4.3708963]
# 8548 [[array([[ 1.460036  ],
#        [ 1.0487318 ],
#        [-0.54158276]], dtype=float32), 5.001305], 4.370696]
# 8549 [[array([[ 1.4600426],
#        [ 1.0487143],
#        [-0.541572 ]], dtype=float32), 5.001305], 4.370549]
# 8550 [[array([[ 1.4600492],
#        [ 1.0486968],
#        [-0.5415612]], dtype=float32), 5.001305], 4.370341]
# 8551 [[array([[ 1.4600557],
#        [ 1.0486792],
#        [-0.5415504]], dtype=float32), 5.001305], 4.3701515]
# 8552 [[array([[ 1.4600623],
#        [ 1.0486617],
#        [-0.5415396]], dtype=float32), 5.001305], 4.3699694]
# 8553 [[array([[ 1.4600688],
#        [ 1.0486442],
#        [-0.5415288]], dtype=float32), 5.001305], 4.369788]
# 8554 [[array([[ 1.4600754 ],
#        [ 1.0486267 ],
#        [-0.54151803]], dtype=float32), 5.001305], 4.3695936]
# 8555 [[array([[ 1.4600819 ],
#        [ 1.0486091 ],
#        [-0.54150724]], dtype=float32), 5.001305], 4.369428]
# 8556 [[array([[ 1.4600885 ],
#        [ 1.0485916 ],
#        [-0.54149646]], dtype=float32), 5.001305], 4.369242]
# 8557 [[array([[ 1.4600952 ],
#        [ 1.0485741 ],
#        [-0.54148567]], dtype=float32), 5.001305], 4.3690615]
# 8558 [[array([[ 1.4601017],
#        [ 1.0485566],
#        [-0.5414749]], dtype=float32), 5.001305], 4.3688674]
# 8559 [[array([[ 1.4601083],
#        [ 1.048539 ],
#        [-0.5414641]], dtype=float32), 5.001305], 4.368663]
# 8560 [[array([[ 1.4601148],
#        [ 1.0485215],
#        [-0.5414533]], dtype=float32), 5.001305], 4.3684793]
# 8561 [[array([[ 1.4601214],
#        [ 1.048504 ],
#        [-0.5414425]], dtype=float32), 5.001305], 4.368293]
# 8562 [[array([[ 1.460128 ],
#        [ 1.0484865],
#        [-0.5414317]], dtype=float32), 5.001305], 4.368109]
# 8563 [[array([[ 1.4601345 ],
#        [ 1.048469  ],
#        [-0.54142094]], dtype=float32), 5.001305], 4.3679085]
# 8564 [[array([[ 1.4601411 ],
#        [ 1.0484514 ],
#        [-0.54141015]], dtype=float32), 5.001305], 4.367715]
# 8565 [[array([[ 1.4601477 ],
#        [ 1.0484339 ],
#        [-0.54139936]], dtype=float32), 5.001305], 4.3675346]
# 8566 [[array([[ 1.4601543],
#        [ 1.0484164],
#        [-0.5413886]], dtype=float32), 5.001305], 4.367383]
# 8567 [[array([[ 1.460161 ],
#        [ 1.0483989],
#        [-0.5413778]], dtype=float32), 5.001305], 4.3671737]
# 8568 [[array([[ 1.4601675],
#        [ 1.0483813],
#        [-0.541367 ]], dtype=float32), 5.001305], 4.36699]
# 8569 [[array([[ 1.4601741],
#        [ 1.0483638],
#        [-0.5413562]], dtype=float32), 5.001305], 4.366823]
# 8570 [[array([[ 1.4601806],
#        [ 1.0483463],
#        [-0.5413454]], dtype=float32), 5.001305], 4.3666105]
# 8571 [[array([[ 1.4601872],
#        [ 1.0483288],
#        [-0.5413346]], dtype=float32), 5.001305], 4.366429]
# 8572 [[array([[ 1.4601938 ],
#        [ 1.0483112 ],
#        [-0.54132384]], dtype=float32), 5.001305], 4.366232]
# 8573 [[array([[ 1.4602003 ],
#        [ 1.0482937 ],
#        [-0.54131305]], dtype=float32), 5.001305], 4.3660593]
# 8574 [[array([[ 1.4602069 ],
#        [ 1.0482762 ],
#        [-0.54130226]], dtype=float32), 5.001305], 4.365857]
# 8575 [[array([[ 1.4602135],
#        [ 1.0482587],
#        [-0.5412915]], dtype=float32), 5.001305], 4.365679]
# 8576 [[array([[ 1.4602201],
#        [ 1.0482411],
#        [-0.5412807]], dtype=float32), 5.001305], 4.365482]
# 8577 [[array([[ 1.4602267],
#        [ 1.0482236],
#        [-0.5412699]], dtype=float32), 5.001305], 4.3653073]
# 8578 [[array([[ 1.4602332],
#        [ 1.0482061],
#        [-0.5412591]], dtype=float32), 5.001305], 4.3650985]
# 8579 [[array([[ 1.4602398],
#        [ 1.0481887],
#        [-0.5412483]], dtype=float32), 5.001305], 4.3649273]
# 8580 [[array([[ 1.4602463 ],
#        [ 1.0481713 ],
#        [-0.54123753]], dtype=float32), 5.001305], 4.3647594]
# 8581 [[array([[ 1.4602529 ],
#        [ 1.0481538 ],
#        [-0.54122674]], dtype=float32), 5.001305], 4.364563]
# 8582 [[array([[ 1.4602594 ],
#        [ 1.0481364 ],
#        [-0.54121596]], dtype=float32), 5.001305], 4.364378]
# 8583 [[array([[ 1.460266  ],
#        [ 1.048119  ],
#        [-0.54120517]], dtype=float32), 5.001305], 4.364188]
# 8584 [[array([[ 1.4602726],
#        [ 1.0481014],
#        [-0.5411944]], dtype=float32), 5.001305], 4.3639994]
# 8585 [[array([[ 1.4602791],
#        [ 1.0480839],
#        [-0.5411836]], dtype=float32), 5.001305], 4.36382]
# 8586 [[array([[ 1.4602857],
#        [ 1.0480665],
#        [-0.5411728]], dtype=float32), 5.001305], 4.3636303]
# 8587 [[array([[ 1.4602922],
#        [ 1.048049 ],
#        [-0.541162 ]], dtype=float32), 5.001305], 4.363437]
# 8588 [[array([[ 1.4602988],
#        [ 1.0480316],
#        [-0.5411512]], dtype=float32), 5.001305], 4.363242]
# 8589 [[array([[ 1.4603053 ],
#        [ 1.048014  ],
#        [-0.54114044]], dtype=float32), 5.001305], 4.363073]
# 8590 [[array([[ 1.4603119 ],
#        [ 1.0479966 ],
#        [-0.54112965]], dtype=float32), 5.001305], 4.3628864]
# 8591 [[array([[ 1.4603184 ],
#        [ 1.0479791 ],
#        [-0.54111886]], dtype=float32), 5.001305], 4.362706]
# 8592 [[array([[ 1.460325 ],
#        [ 1.0479617],
#        [-0.5411081]], dtype=float32), 5.001305], 4.3625255]
# 8593 [[array([[ 1.4603316],
#        [ 1.0479443],
#        [-0.5410973]], dtype=float32), 5.001305], 4.362346]
# 8594 [[array([[ 1.4603381],
#        [ 1.0479268],
#        [-0.5410865]], dtype=float32), 5.001305], 4.362134]
# 8595 [[array([[ 1.4603447],
#        [ 1.0479093],
#        [-0.5410757]], dtype=float32), 5.001305], 4.3619685]
# 8596 [[array([[ 1.4603512],
#        [ 1.0478919],
#        [-0.5410649]], dtype=float32), 5.001305], 4.3617697]
# 8597 [[array([[ 1.4603578],
#        [ 1.0478745],
#        [-0.5410541]], dtype=float32), 5.001305], 4.361562]
# 8598 [[array([[ 1.4603643 ],
#        [ 1.0478569 ],
#        [-0.54104334]], dtype=float32), 5.001305], 4.3614025]
# 8599 [[array([[ 1.4603709 ],
#        [ 1.0478394 ],
#        [-0.54103255]], dtype=float32), 5.001305], 4.3612347]
# 8600 [[array([[ 1.4603775 ],
#        [ 1.047822  ],
#        [-0.54102176]], dtype=float32), 5.001305], 4.36103]
# 8601 [[array([[ 1.460384 ],
#        [ 1.0478045],
#        [-0.541011 ]], dtype=float32), 5.001305], 4.360861]
# 8602 [[array([[ 1.4603906],
#        [ 1.0477871],
#        [-0.5410002]], dtype=float32), 5.001305], 4.360657]
# 8603 [[array([[ 1.4603971],
#        [ 1.0477697],
#        [-0.5409894]], dtype=float32), 5.001305], 4.3604693]
# 8604 [[array([[ 1.4604037],
#        [ 1.0477521],
#        [-0.5409786]], dtype=float32), 5.001305], 4.3603125]
# 8605 [[array([[ 1.4604102],
#        [ 1.0477347],
#        [-0.5409678]], dtype=float32), 5.001305], 4.3600903]
# 8606 [[array([[ 1.4604168 ],
#        [ 1.0477173 ],
#        [-0.54095703]], dtype=float32), 5.001305], 4.359929]
# 8607 [[array([[ 1.4604234 ],
#        [ 1.0476998 ],
#        [-0.54094625]], dtype=float32), 5.001305], 4.3597364]
# 8608 [[array([[ 1.4604299 ],
#        [ 1.0476824 ],
#        [-0.54093546]], dtype=float32), 5.001305], 4.359538]
# 8609 [[array([[ 1.4604365 ],
#        [ 1.0476649 ],
#        [-0.54092467]], dtype=float32), 5.001305], 4.359376]
# 8610 [[array([[ 1.460443 ],
#        [ 1.0476475],
#        [-0.5409139]], dtype=float32), 5.001305], 4.359188]
# 8611 [[array([[ 1.4604496 ],
#        [ 1.04763   ],
#        [-0.54090315]], dtype=float32), 5.001305], 4.358995]
# 8612 [[array([[ 1.4604561 ],
#        [ 1.0476125 ],
#        [-0.54089236]], dtype=float32), 5.001305], 4.358798]
# 8613 [[array([[ 1.4604627 ],
#        [ 1.047595  ],
#        [-0.54088163]], dtype=float32), 5.001305], 4.358611]
# 8614 [[array([[ 1.4604692 ],
#        [ 1.0475776 ],
#        [-0.54087085]], dtype=float32), 5.001305], 4.3584623]
# 8615 [[array([[ 1.4604758],
#        [ 1.0475602],
#        [-0.5408601]], dtype=float32), 5.001305], 4.358264]
# 8616 [[array([[ 1.4604824],
#        [ 1.0475428],
#        [-0.5408494]], dtype=float32), 5.001305], 4.3580523]
# 8617 [[array([[ 1.4604889 ],
#        [ 1.0475254 ],
#        [-0.54083866]], dtype=float32), 5.001305], 4.3579106]
# 8618 [[array([[ 1.4604955 ],
#        [ 1.047508  ],
#        [-0.54082793]], dtype=float32), 5.001305], 4.3576984]
# 8619 [[array([[ 1.460502 ],
#        [ 1.0474906],
#        [-0.5408172]], dtype=float32), 5.001305], 4.3575177]
# 8620 [[array([[ 1.4605086],
#        [ 1.0474732],
#        [-0.5408065]], dtype=float32), 5.001305], 4.3573194]
# 8621 [[array([[ 1.4605151 ],
#        [ 1.0474558 ],
#        [-0.54079574]], dtype=float32), 5.001305], 4.3571076]
# 8622 [[array([[ 1.4605217],
#        [ 1.0474384],
#        [-0.540785 ]], dtype=float32), 5.001305], 4.3569574]
# 8623 [[array([[ 1.4605283],
#        [ 1.047421 ],
#        [-0.5407743]], dtype=float32), 5.001305], 4.356776]
# 8624 [[array([[ 1.4605348 ],
#        [ 1.0474036 ],
#        [-0.54076356]], dtype=float32), 5.001305], 4.356551]
# 8625 [[array([[ 1.4605414],
#        [ 1.0473862],
#        [-0.5407528]], dtype=float32), 5.001305], 4.356412]
# 8626 [[array([[ 1.4605479],
#        [ 1.0473688],
#        [-0.5407421]], dtype=float32), 5.001305], 4.356219]
# 8627 [[array([[ 1.4605545],
#        [ 1.0473514],
#        [-0.5407314]], dtype=float32), 5.001305], 4.356017]
# 8628 [[array([[ 1.460561  ],
#        [ 1.047334  ],
#        [-0.54072064]], dtype=float32), 5.001305], 4.3558598]
# 8629 [[array([[ 1.4605676],
#        [ 1.0473166],
#        [-0.5407099]], dtype=float32), 5.001305], 4.3556376]
# 8630 [[array([[ 1.4605742],
#        [ 1.0472991],
#        [-0.5406992]], dtype=float32), 5.001305], 4.3554754]
# 8631 [[array([[ 1.4605807 ],
#        [ 1.0472817 ],
#        [-0.54068846]], dtype=float32), 5.001305], 4.3552847]
# 8632 [[array([[ 1.4605873],
#        [ 1.0472643],
#        [-0.5406777]], dtype=float32), 5.001305], 4.3551316]
# 8633 [[array([[ 1.4605938],
#        [ 1.0472469],
#        [-0.540667 ]], dtype=float32), 5.001305], 4.3549566]
# 8634 [[array([[ 1.4606004 ],
#        [ 1.0472295 ],
#        [-0.54065627]], dtype=float32), 5.001305], 4.3547344]
# 8635 [[array([[ 1.4606069 ],
#        [ 1.0472121 ],
#        [-0.54064554]], dtype=float32), 5.001305], 4.354556]
# 8636 [[array([[ 1.4606135],
#        [ 1.0471947],
#        [-0.5406348]], dtype=float32), 5.001305], 4.3543906]
# 8637 [[array([[ 1.46062  ],
#        [ 1.0471773],
#        [-0.5406241]], dtype=float32), 5.001305], 4.3541837]
# 8638 [[array([[ 1.4606266 ],
#        [ 1.0471599 ],
#        [-0.54061335]], dtype=float32), 5.001305], 4.354003]
# 8639 [[array([[ 1.4606332],
#        [ 1.0471425],
#        [-0.5406026]], dtype=float32), 5.001305], 4.3538103]
# 8640 [[array([[ 1.4606397],
#        [ 1.0471251],
#        [-0.5405919]], dtype=float32), 5.001305], 4.3536215]
# 8641 [[array([[ 1.4606463 ],
#        [ 1.0471077 ],
#        [-0.54058117]], dtype=float32), 5.001305], 4.353469]
# 8642 [[array([[ 1.4606528 ],
#        [ 1.0470903 ],
#        [-0.54057044]], dtype=float32), 5.001305], 4.3532495]
# 8643 [[array([[ 1.4606594],
#        [ 1.0470729],
#        [-0.5405597]], dtype=float32), 5.001305], 4.3530684]
# 8644 [[array([[ 1.460666 ],
#        [ 1.0470555],
#        [-0.540549 ]], dtype=float32), 5.001305], 4.3528943]
# 8645 [[array([[ 1.4606725 ],
#        [ 1.0470381 ],
#        [-0.54053825]], dtype=float32), 5.001305], 4.3527055]
# 8646 [[array([[ 1.460679 ],
#        [ 1.0470207],
#        [-0.5405275]], dtype=float32), 5.001305], 4.352494]
# 8647 [[array([[ 1.4606855],
#        [ 1.0470033],
#        [-0.5405168]], dtype=float32), 5.001305], 4.352329]
# 8648 [[array([[ 1.460692  ],
#        [ 1.0469859 ],
#        [-0.54050606]], dtype=float32), 5.001305], 4.3521605]
# 8649 [[array([[ 1.4606986 ],
#        [ 1.0469685 ],
#        [-0.54049534]], dtype=float32), 5.001305], 4.3519816]
# 8650 [[array([[ 1.4607052],
#        [ 1.046951 ],
#        [-0.5404846]], dtype=float32), 5.001305], 4.3517804]
# 8651 [[array([[ 1.4607117],
#        [ 1.0469337],
#        [-0.5404739]], dtype=float32), 5.001305], 4.351609]
# 8652 [[array([[ 1.4607182 ],
#        [ 1.0469162 ],
#        [-0.54046315]], dtype=float32), 5.001305], 4.3514247]
# 8653 [[array([[ 1.4607246],
#        [ 1.0468988],
#        [-0.5404524]], dtype=float32), 5.001305], 4.351245]
# 8654 [[array([[ 1.4607311],
#        [ 1.0468814],
#        [-0.5404417]], dtype=float32), 5.001305], 4.351039]
# 8655 [[array([[ 1.4607377 ],
#        [ 1.046864  ],
#        [-0.54043096]], dtype=float32), 5.001305], 4.350876]
# 8656 [[array([[ 1.4607441 ],
#        [ 1.0468466 ],
#        [-0.54042023]], dtype=float32), 5.001305], 4.350671]
# 8657 [[array([[ 1.4607507],
#        [ 1.0468292],
#        [-0.5404095]], dtype=float32), 5.001305], 4.350467]
# 8658 [[array([[ 1.4607573],
#        [ 1.0468118],
#        [-0.5403988]], dtype=float32), 5.001305], 4.350306]
# 8659 [[array([[ 1.4607637 ],
#        [ 1.0467944 ],
#        [-0.54038805]], dtype=float32), 5.001305], 4.350108]
# 8660 [[array([[ 1.4607702],
#        [ 1.046777 ],
#        [-0.5403773]], dtype=float32), 5.001305], 4.3499546]
# 8661 [[array([[ 1.4607768],
#        [ 1.0467596],
#        [-0.5403666]], dtype=float32), 5.001305], 4.34974]
# 8662 [[array([[ 1.4607832 ],
#        [ 1.0467422 ],
#        [-0.54035586]], dtype=float32), 5.001305], 4.3495417]
# 8663 [[array([[ 1.4607898 ],
#        [ 1.0467248 ],
#        [-0.54034513]], dtype=float32), 5.001305], 4.349385]
# 8664 [[array([[ 1.4607962],
#        [ 1.0467074],
#        [-0.5403344]], dtype=float32), 5.001305], 4.3492103]
# 8665 [[array([[ 1.4608028],
#        [ 1.04669  ],
#        [-0.5403237]], dtype=float32), 5.001305], 4.3490076]
# 8666 [[array([[ 1.4608094 ],
#        [ 1.0466726 ],
#        [-0.54031295]], dtype=float32), 5.001305], 4.3488407]
# 8667 [[array([[ 1.4608158],
#        [ 1.0466552],
#        [-0.5403022]], dtype=float32), 5.001305], 4.3486586]
# 8668 [[array([[ 1.4608223],
#        [ 1.0466378],
#        [-0.5402915]], dtype=float32), 5.001305], 4.348492]
# 8669 [[array([[ 1.4608289 ],
#        [ 1.0466204 ],
#        [-0.54028076]], dtype=float32), 5.001305], 4.3482533]
# 8670 [[array([[ 1.4608353 ],
#        [ 1.046603  ],
#        [-0.54027003]], dtype=float32), 5.001305], 4.3480864]
# 8671 [[array([[ 1.4608419],
#        [ 1.0465856],
#        [-0.5402593]], dtype=float32), 5.001305], 4.3479342]
# 8672 [[array([[ 1.4608483],
#        [ 1.0465682],
#        [-0.5402486]], dtype=float32), 5.001305], 4.34772]
# 8673 [[array([[ 1.4608549 ],
#        [ 1.0465508 ],
#        [-0.54023784]], dtype=float32), 5.001305], 4.3475485]
# 8674 [[array([[ 1.4608614],
#        [ 1.0465333],
#        [-0.5402271]], dtype=float32), 5.001305], 4.347378]
# 8675 [[array([[ 1.4608679],
#        [ 1.046516 ],
#        [-0.5402164]], dtype=float32), 5.001305], 4.347157]
# 8676 [[array([[ 1.4608744 ],
#        [ 1.0464985 ],
#        [-0.54020566]], dtype=float32), 5.001305], 4.346985]
# 8677 [[array([[ 1.460881 ],
#        [ 1.0464811],
#        [-0.5401949]], dtype=float32), 5.001305], 4.3468084]
# 8678 [[array([[ 1.4608876],
#        [ 1.0464637],
#        [-0.5401842]], dtype=float32), 5.001305], 4.3466206]
# 8679 [[array([[ 1.460894 ],
#        [ 1.0464463],
#        [-0.5401735]], dtype=float32), 5.001305], 4.3464403]
# 8680 [[array([[ 1.4609005 ],
#        [ 1.0464289 ],
#        [-0.54016274]], dtype=float32), 5.001305], 4.346229]
# 8681 [[array([[ 1.460907 ],
#        [ 1.0464115],
#        [-0.540152 ]], dtype=float32), 5.001305], 4.346074]
# 8682 [[array([[ 1.4609135],
#        [ 1.0463941],
#        [-0.5401413]], dtype=float32), 5.001305], 4.345888]
# 8683 [[array([[ 1.4609201 ],
#        [ 1.0463767 ],
#        [-0.54013056]], dtype=float32), 5.001305], 4.345708]
# 8684 [[array([[ 1.4609267],
#        [ 1.0463593],
#        [-0.5401198]], dtype=float32), 5.001305], 4.3455114]
# 8685 [[array([[ 1.4609331],
#        [ 1.0463419],
#        [-0.5401091]], dtype=float32), 5.001305], 4.3453097]
# 8686 [[array([[ 1.4609396 ],
#        [ 1.0463245 ],
#        [-0.54009837]], dtype=float32), 5.001305], 4.345176]
# 8687 [[array([[ 1.4609461 ],
#        [ 1.0463071 ],
#        [-0.54008764]], dtype=float32), 5.001305], 4.344961]
# 8688 [[array([[ 1.4609525],
#        [ 1.0462897],
#        [-0.5400769]], dtype=float32), 5.001305], 4.3447714]
# 8689 [[array([[ 1.4609591],
#        [ 1.0462723],
#        [-0.5400662]], dtype=float32), 5.001305], 4.3446054]
# 8690 [[array([[ 1.4609655 ],
#        [ 1.0462549 ],
#        [-0.54005545]], dtype=float32), 5.001305], 4.344413]
# 8691 [[array([[ 1.4609721],
#        [ 1.0462375],
#        [-0.5400447]], dtype=float32), 5.001305], 4.3442197]
# 8692 [[array([[ 1.4609786],
#        [ 1.0462201],
#        [-0.540034 ]], dtype=float32), 5.001305], 4.3440595]
# 8693 [[array([[ 1.4609851 ],
#        [ 1.0462027 ],
#        [-0.54002327]], dtype=float32), 5.001305], 4.343852]
# 8694 [[array([[ 1.4609916 ],
#        [ 1.0461853 ],
#        [-0.54001254]], dtype=float32), 5.001305], 4.343667]
# 8695 [[array([[ 1.4609982],
#        [ 1.0461679],
#        [-0.5400018]], dtype=float32), 5.001305], 4.3435035]
# 8696 [[array([[ 1.4610046],
#        [ 1.0461504],
#        [-0.5399911]], dtype=float32), 5.001305], 4.34332]
# 8697 [[array([[ 1.4610112 ],
#        [ 1.046133  ],
#        [-0.53998035]], dtype=float32), 5.001305], 4.343135]
# 8698 [[array([[ 1.4610177],
#        [ 1.0461156],
#        [-0.5399696]], dtype=float32), 5.001305], 4.3429236]
# 8699 [[array([[ 1.4610242],
#        [ 1.0460982],
#        [-0.5399589]], dtype=float32), 5.001305], 4.342759]
# 8700 [[array([[ 1.4610307 ],
#        [ 1.0460808 ],
#        [-0.53994817]], dtype=float32), 5.001305], 4.3425894]
# 8701 [[array([[ 1.4610373 ],
#        [ 1.0460634 ],
#        [-0.53993744]], dtype=float32), 5.001305], 4.3424053]
# 8702 [[array([[ 1.4610437],
#        [ 1.046046 ],
#        [-0.5399267]], dtype=float32), 5.001305], 4.3421984]
# 8703 [[array([[ 1.4610503],
#        [ 1.0460286],
#        [-0.539916 ]], dtype=float32), 5.001305], 4.3420324]
# 8704 [[array([[ 1.4610567 ],
#        [ 1.0460112 ],
#        [-0.53990525]], dtype=float32), 5.001305], 4.3418365]
# 8705 [[array([[ 1.4610633],
#        [ 1.0459938],
#        [-0.5398945]], dtype=float32), 5.001305], 4.3416643]
# 8706 [[array([[ 1.4610698],
#        [ 1.0459764],
#        [-0.5398838]], dtype=float32), 5.001305], 4.341473]
# 8707 [[array([[ 1.4610764 ],
#        [ 1.045959  ],
#        [-0.53987306]], dtype=float32), 5.001305], 4.3412933]
# 8708 [[array([[ 1.4610828 ],
#        [ 1.0459416 ],
#        [-0.53986233]], dtype=float32), 5.001305], 4.3411055]
# 8709 [[array([[ 1.4610894],
#        [ 1.0459243],
#        [-0.5398516]], dtype=float32), 5.001305], 4.3409214]
# 8710 [[array([[ 1.4610958],
#        [ 1.0459069],
#        [-0.5398409]], dtype=float32), 5.001305], 4.340707]
# 8711 [[array([[ 1.4611022 ],
#        [ 1.0458896 ],
#        [-0.53983015]], dtype=float32), 5.001305], 4.3405447]
# 8712 [[array([[ 1.4611087],
#        [ 1.0458723],
#        [-0.5398194]], dtype=float32), 5.001305], 4.3403883]
# 8713 [[array([[ 1.4611151],
#        [ 1.045855 ],
#        [-0.5398087]], dtype=float32), 5.001305], 4.340211]
# 8714 [[array([[ 1.4611216 ],
#        [ 1.0458378 ],
#        [-0.53979796]], dtype=float32), 5.001305], 4.339982]
# 8715 [[array([[ 1.461128  ],
#        [ 1.0458205 ],
#        [-0.53978723]], dtype=float32), 5.001305], 4.3398256]
# 8716 [[array([[ 1.4611344],
#        [ 1.0458032],
#        [-0.5397765]], dtype=float32), 5.001305], 4.339663]
# 8717 [[array([[ 1.4611409],
#        [ 1.0457859],
#        [-0.5397658]], dtype=float32), 5.001305], 4.339476]
# 8718 [[array([[ 1.4611473 ],
#        [ 1.0457686 ],
#        [-0.53975505]], dtype=float32), 5.001305], 4.339257]
# 8719 [[array([[ 1.4611537],
#        [ 1.0457513],
#        [-0.5397443]], dtype=float32), 5.001305], 4.3391004]
# 8720 [[array([[ 1.4611602],
#        [ 1.045734 ],
#        [-0.5397336]], dtype=float32), 5.001305], 4.338907]
# 8721 [[array([[ 1.4611666 ],
#        [ 1.0457168 ],
#        [-0.53972286]], dtype=float32), 5.001305], 4.3387337]
# 8722 [[array([[ 1.461173  ],
#        [ 1.0456995 ],
#        [-0.53971213]], dtype=float32), 5.001305], 4.3385596]
# 8723 [[array([[ 1.4611795],
#        [ 1.0456822],
#        [-0.5397014]], dtype=float32), 5.001305], 4.3383384]
# 8724 [[array([[ 1.4611859],
#        [ 1.0456649],
#        [-0.5396907]], dtype=float32), 5.001305], 4.3381824]
# 8725 [[array([[ 1.4611924 ],
#        [ 1.0456476 ],
#        [-0.53967994]], dtype=float32), 5.001305], 4.337995]
# 8726 [[array([[ 1.4611988],
#        [ 1.0456303],
#        [-0.5396692]], dtype=float32), 5.001305], 4.337804]
# 8727 [[array([[ 1.4612052],
#        [ 1.045613 ],
#        [-0.5396585]], dtype=float32), 5.001305], 4.33761]
# 8728 [[array([[ 1.4612117 ],
#        [ 1.0455958 ],
#        [-0.53964776]], dtype=float32), 5.001305], 4.337473]
# 8729 [[array([[ 1.4612181],
#        [ 1.0455785],
#        [-0.539637 ]], dtype=float32), 5.001305], 4.3372707]
# 8730 [[array([[ 1.4612246],
#        [ 1.0455612],
#        [-0.5396263]], dtype=float32), 5.001305], 4.337079]
# 8731 [[array([[ 1.461231 ],
#        [ 1.0455439],
#        [-0.5396156]], dtype=float32), 5.001305], 4.336901]
# 8732 [[array([[ 1.4612374 ],
#        [ 1.0455266 ],
#        [-0.53960484]], dtype=float32), 5.001305], 4.3367453]
# 8733 [[array([[ 1.4612439],
#        [ 1.0455093],
#        [-0.5395941]], dtype=float32), 5.001305], 4.3365245]
# 8734 [[array([[ 1.4612503],
#        [ 1.045492 ],
#        [-0.5395834]], dtype=float32), 5.001305], 4.336339]
# 8735 [[array([[ 1.4612567 ],
#        [ 1.0454748 ],
#        [-0.53957266]], dtype=float32), 5.001305], 4.3361893]
# 8736 [[array([[ 1.4612632],
#        [ 1.0454575],
#        [-0.5395619]], dtype=float32), 5.001305], 4.3359656]
# 8737 [[array([[ 1.4612696],
#        [ 1.0454402],
#        [-0.5395512]], dtype=float32), 5.001305], 4.335797]
# 8738 [[array([[ 1.461276  ],
#        [ 1.0454229 ],
#        [-0.53954047]], dtype=float32), 5.001305], 4.335627]
# 8739 [[array([[ 1.4612825 ],
#        [ 1.0454056 ],
#        [-0.53952974]], dtype=float32), 5.001305], 4.33543]
# 8740 [[array([[ 1.4612889],
#        [ 1.0453883],
#        [-0.539519 ]], dtype=float32), 5.001305], 4.3352556]
# 8741 [[array([[ 1.4612954],
#        [ 1.045371 ],
#        [-0.5395083]], dtype=float32), 5.001305], 4.3350725]
# 8742 [[array([[ 1.4613018 ],
#        [ 1.0453538 ],
#        [-0.53949755]], dtype=float32), 5.001305], 4.3348756]
# 8743 [[array([[ 1.4613082],
#        [ 1.0453365],
#        [-0.5394868]], dtype=float32), 5.001305], 4.3347197]
# 8744 [[array([[ 1.4613147],
#        [ 1.0453192],
#        [-0.5394761]], dtype=float32), 5.001305], 4.3345084]
# 8745 [[array([[ 1.4613211 ],
#        [ 1.0453019 ],
#        [-0.53946537]], dtype=float32), 5.001305], 4.3343725]
# 8746 [[array([[ 1.4613276 ],
#        [ 1.0452846 ],
#        [-0.53945464]], dtype=float32), 5.001305], 4.3341513]
# 8747 [[array([[ 1.461334 ],
#        [ 1.0452673],
#        [-0.5394439]], dtype=float32), 5.001305], 4.333986]
# 8748 [[array([[ 1.4613404],
#        [ 1.04525  ],
#        [-0.5394332]], dtype=float32), 5.001305], 4.3337984]
# 8749 [[array([[ 1.4613469 ],
#        [ 1.0452328 ],
#        [-0.53942245]], dtype=float32), 5.001305], 4.3335876]
# 8750 [[array([[ 1.4613533],
#        [ 1.0452155],
#        [-0.5394117]], dtype=float32), 5.001305], 4.333424]
# 8751 [[array([[ 1.4613597],
#        [ 1.0451982],
#        [-0.539401 ]], dtype=float32), 5.001305], 4.3332276]
# 8752 [[array([[ 1.4613662 ],
#        [ 1.0451809 ],
#        [-0.53939027]], dtype=float32), 5.001305], 4.333061]
# 8753 [[array([[ 1.4613726 ],
#        [ 1.0451636 ],
#        [-0.53937954]], dtype=float32), 5.001305], 4.3328786]
# 8754 [[array([[ 1.461379 ],
#        [ 1.0451463],
#        [-0.5393688]], dtype=float32), 5.001305], 4.3327003]
# 8755 [[array([[ 1.4613855],
#        [ 1.0451291],
#        [-0.5393581]], dtype=float32), 5.001305], 4.33249]
# 8756 [[array([[ 1.4613919 ],
#        [ 1.0451118 ],
#        [-0.53934735]], dtype=float32), 5.001305], 4.3323445]
# 8757 [[array([[ 1.4613984],
#        [ 1.0450945],
#        [-0.5393366]], dtype=float32), 5.001305], 4.3321643]
# 8758 [[array([[ 1.4614048],
#        [ 1.0450772],
#        [-0.5393259]], dtype=float32), 5.001305], 4.3319674]
# 8759 [[array([[ 1.4614112 ],
#        [ 1.0450599 ],
#        [-0.53931516]], dtype=float32), 5.001305], 4.3317666]
# 8760 [[array([[ 1.4614177 ],
#        [ 1.0450426 ],
#        [-0.53930444]], dtype=float32), 5.001305], 4.3316164]
# 8761 [[array([[ 1.4614241],
#        [ 1.0450253],
#        [-0.5392937]], dtype=float32), 5.001305], 4.3314276]
# 8762 [[array([[ 1.4614305 ],
#        [ 1.0450081 ],
#        [-0.53928304]], dtype=float32), 5.001305], 4.3312125]
# 8763 [[array([[ 1.461437  ],
#        [ 1.0449908 ],
#        [-0.53927237]], dtype=float32), 5.001305], 4.3310575]
# 8764 [[array([[ 1.4614434 ],
#        [ 1.0449735 ],
#        [-0.53926164]], dtype=float32), 5.001305], 4.3308744]
# 8765 [[array([[ 1.4614499],
#        [ 1.0449562],
#        [-0.5392509]], dtype=float32), 5.001305], 4.330677]
# 8766 [[array([[ 1.4614563 ],
#        [ 1.0449389 ],
#        [-0.53924024]], dtype=float32), 5.001305], 4.3305135]
# 8767 [[array([[ 1.4614627],
#        [ 1.0449216],
#        [-0.5392295]], dtype=float32), 5.001305], 4.3303404]
# 8768 [[array([[ 1.4614692],
#        [ 1.0449044],
#        [-0.5392188]], dtype=float32), 5.001305], 4.330188]
# 8769 [[array([[ 1.4614756 ],
#        [ 1.0448871 ],
#        [-0.53920805]], dtype=float32), 5.001305], 4.3299856]
# 8770 [[array([[ 1.461482 ],
# ...
#        [ 1.0267023],
#        [-0.5277178]], dtype=float32), 5.001305], 4.143476]
# 9855 [[array([[ 1.4680234 ],
#        [ 1.0266861 ],
#        [-0.52770734]], dtype=float32), 5.001305], 4.143287]
# 9856 [[array([[ 1.468029 ],
#        [ 1.0266699],
#        [-0.5276969]], dtype=float32), 5.001305], 4.1431313]
# 9857 [[array([[ 1.4680346],
#        [ 1.0266536],
#        [-0.5276865]], dtype=float32), 5.001305], 4.1429586]
# 9858 [[array([[ 1.4680402],
#        [ 1.0266374],
#        [-0.527676 ]], dtype=float32), 5.001305], 4.1428]
# 9859 [[array([[ 1.4680458],
#        [ 1.0266212],
#        [-0.5276655]], dtype=float32), 5.001305], 4.1426373]
# 9860 [[array([[ 1.4680514 ],
#        [ 1.026605  ],
#        [-0.52765507]], dtype=float32), 5.001305], 4.142495]
# 9861 [[array([[ 1.468057 ],
#        [ 1.0265888],
#        [-0.5276446]], dtype=float32), 5.001305], 4.142326]
# 9862 [[array([[ 1.4680626 ],
#        [ 1.0265726 ],
#        [-0.52763414]], dtype=float32), 5.001305], 4.1421766]
# 9863 [[array([[ 1.4680682],
#        [ 1.0265564],
#        [-0.5276237]], dtype=float32), 5.001305], 4.141988]
# 9864 [[array([[ 1.4680738],
#        [ 1.0265402],
#        [-0.5276132]], dtype=float32), 5.001305], 4.1418424]
# 9865 [[array([[ 1.4680794 ],
#        [ 1.026524  ],
#        [-0.52760273]], dtype=float32), 5.001305], 4.1416636]
# 9866 [[array([[ 1.468085  ],
#        [ 1.0265077 ],
#        [-0.52759224]], dtype=float32), 5.001305], 4.141511]
# 9867 [[array([[ 1.4680907 ],
#        [ 1.0264915 ],
#        [-0.52758175]], dtype=float32), 5.001305], 4.141382]
# 9868 [[array([[ 1.4680963 ],
#        [ 1.0264753 ],
#        [-0.52757126]], dtype=float32), 5.001305], 4.1411867]
# 9869 [[array([[ 1.4681019 ],
#        [ 1.0264591 ],
#        [-0.52756083]], dtype=float32), 5.001305], 4.1410303]
# 9870 [[array([[ 1.4681075],
#        [ 1.0264429],
#        [-0.5275504]], dtype=float32), 5.001305], 4.1408854]
# 9871 [[array([[ 1.4681131 ],
#        [ 1.0264267 ],
#        [-0.52753997]], dtype=float32), 5.001305], 4.1406736]
# 9872 [[array([[ 1.4681187 ],
#        [ 1.0264105 ],
#        [-0.52752954]], dtype=float32), 5.001305], 4.1405673]
# 9873 [[array([[ 1.4681243 ],
#        [ 1.0263942 ],
#        [-0.52751905]], dtype=float32), 5.001305], 4.140382]
# 9874 [[array([[ 1.4681299 ],
#        [ 1.026378  ],
#        [-0.52750856]], dtype=float32), 5.001305], 4.1402135]
# 9875 [[array([[ 1.4681355 ],
#        [ 1.0263618 ],
#        [-0.52749807]], dtype=float32), 5.001305], 4.140061]
# 9876 [[array([[ 1.4681411 ],
#        [ 1.0263456 ],
#        [-0.52748764]], dtype=float32), 5.001305], 4.139905]
# 9877 [[array([[ 1.4681467 ],
#        [ 1.0263294 ],
#        [-0.52747715]], dtype=float32), 5.001305], 4.13974]
# 9878 [[array([[ 1.4681523 ],
#        [ 1.0263132 ],
#        [-0.52746665]], dtype=float32), 5.001305], 4.139568]
# 9879 [[array([[ 1.4681579],
#        [ 1.026297 ],
#        [-0.5274562]], dtype=float32), 5.001305], 4.139398]
# 9880 [[array([[ 1.4681635 ],
#        [ 1.0262808 ],
#        [-0.52744573]], dtype=float32), 5.001305], 4.1392565]
# 9881 [[array([[ 1.4681691],
#        [ 1.0262645],
#        [-0.5274353]], dtype=float32), 5.001305], 4.1390944]
# 9882 [[array([[ 1.4681747],
#        [ 1.0262483],
#        [-0.5274248]], dtype=float32), 5.001305], 4.138949]
# 9883 [[array([[ 1.4681803],
#        [ 1.0262321],
#        [-0.5274143]], dtype=float32), 5.001305], 4.138747]
# 9884 [[array([[ 1.4681859],
#        [ 1.0262159],
#        [-0.5274039]], dtype=float32), 5.001305], 4.138598]
# 9885 [[array([[ 1.4681915],
#        [ 1.0261997],
#        [-0.5273934]], dtype=float32), 5.001305], 4.1384425]
# 9886 [[array([[ 1.4681971],
#        [ 1.0261835],
#        [-0.5273829]], dtype=float32), 5.001305], 4.13829]
# 9887 [[array([[ 1.4682027],
#        [ 1.0261673],
#        [-0.5273725]], dtype=float32), 5.001305], 4.1381288]
# 9888 [[array([[ 1.4682083 ],
#        [ 1.0261511 ],
#        [-0.52736205]], dtype=float32), 5.001305], 4.1379623]
# 9889 [[array([[ 1.4682139 ],
#        [ 1.0261348 ],
#        [-0.52735156]], dtype=float32), 5.001305], 4.1377974]
# 9890 [[array([[ 1.4682195 ],
#        [ 1.0261186 ],
#        [-0.52734107]], dtype=float32), 5.001305], 4.1376414]
# 9891 [[array([[ 1.4682251 ],
#        [ 1.0261024 ],
#        [-0.52733064]], dtype=float32), 5.001305], 4.137473]
# 9892 [[array([[ 1.4682307],
#        [ 1.0260862],
#        [-0.5273202]], dtype=float32), 5.001305], 4.1373043]
# 9893 [[array([[ 1.4682363],
#        [ 1.02607  ],
#        [-0.5273097]], dtype=float32), 5.001305], 4.1371565]
# 9894 [[array([[ 1.4682419],
#        [ 1.0260538],
#        [-0.5272992]], dtype=float32), 5.001305], 4.137007]
# 9895 [[array([[ 1.4682475],
#        [ 1.0260376],
#        [-0.5272888]], dtype=float32), 5.001305], 4.1368375]
# 9896 [[array([[ 1.4682531],
#        [ 1.0260214],
#        [-0.5272783]], dtype=float32), 5.001305], 4.1366534]
# 9897 [[array([[ 1.4682587],
#        [ 1.0260051],
#        [-0.5272679]], dtype=float32), 5.001305], 4.1365075]
# 9898 [[array([[ 1.4682643],
#        [ 1.0259889],
#        [-0.5272574]], dtype=float32), 5.001305], 4.1363587]
# 9899 [[array([[ 1.46827  ],
#        [ 1.0259727],
#        [-0.5272469]], dtype=float32), 5.001305], 4.1361775]
# 9900 [[array([[ 1.4682755],
#        [ 1.0259565],
#        [-0.5272364]], dtype=float32), 5.001305], 4.1360145]
# 9901 [[array([[ 1.4682811],
#        [ 1.0259403],
#        [-0.527226 ]], dtype=float32), 5.001305], 4.135873]
# 9902 [[array([[ 1.4682868],
#        [ 1.0259241],
#        [-0.5272155]], dtype=float32), 5.001305], 4.1357174]
# 9903 [[array([[ 1.4682924 ],
#        [ 1.0259079 ],
#        [-0.52720505]], dtype=float32), 5.001305], 4.135512]
# 9904 [[array([[ 1.468298  ],
#        [ 1.0258917 ],
#        [-0.52719456]], dtype=float32), 5.001305], 4.1353803]
# 9905 [[array([[ 1.4683036 ],
#        [ 1.0258754 ],
#        [-0.52718407]], dtype=float32), 5.001305], 4.1351976]
# 9906 [[array([[ 1.4683092],
#        [ 1.0258592],
#        [-0.5271736]], dtype=float32), 5.001305], 4.13507]
# 9907 [[array([[ 1.4683148 ],
#        [ 1.025843  ],
#        [-0.52716315]], dtype=float32), 5.001305], 4.134907]
# 9908 [[array([[ 1.4683204],
#        [ 1.0258268],
#        [-0.5271527]], dtype=float32), 5.001305], 4.1347313]
# 9909 [[array([[ 1.468326 ],
#        [ 1.0258106],
#        [-0.5271422]], dtype=float32), 5.001305], 4.134571]
# 9910 [[array([[ 1.4683316],
#        [ 1.0257944],
#        [-0.5271318]], dtype=float32), 5.001305], 4.1344247]
# 9911 [[array([[ 1.4683372],
#        [ 1.0257782],
#        [-0.5271213]], dtype=float32), 5.001305], 4.1342273]
# 9912 [[array([[ 1.4683428],
#        [ 1.025762 ],
#        [-0.5271108]], dtype=float32), 5.001305], 4.1340685]
# 9913 [[array([[ 1.4683484],
#        [ 1.0257457],
#        [-0.5271004]], dtype=float32), 5.001305], 4.1339283]
# 9914 [[array([[ 1.468354 ],
#        [ 1.0257295],
#        [-0.5270899]], dtype=float32), 5.001305], 4.1337547]
# 9915 [[array([[ 1.4683596],
#        [ 1.0257133],
#        [-0.5270794]], dtype=float32), 5.001305], 4.1335993]
# 9916 [[array([[ 1.4683652],
#        [ 1.0256971],
#        [-0.527069 ]], dtype=float32), 5.001305], 4.133436]
# 9917 [[array([[ 1.4683708 ],
#        [ 1.0256809 ],
#        [-0.52705854]], dtype=float32), 5.001305], 4.133294]
# 9918 [[array([[ 1.4683764 ],
#        [ 1.0256647 ],
#        [-0.52704805]], dtype=float32), 5.001305], 4.133137]
# 9919 [[array([[ 1.468382  ],
#        [ 1.0256485 ],
#        [-0.52703756]], dtype=float32), 5.001305], 4.132935]
# 9920 [[array([[ 1.4683876 ],
#        [ 1.0256323 ],
#        [-0.52702713]], dtype=float32), 5.001305], 4.132802]
# 9921 [[array([[ 1.4683932 ],
#        [ 1.025616  ],
#        [-0.52701664]], dtype=float32), 5.001305], 4.1326184]
# 9922 [[array([[ 1.4683988],
#        [ 1.0255998],
#        [-0.5270062]], dtype=float32), 5.001305], 4.132476]
# 9923 [[array([[ 1.4684044],
#        [ 1.0255836],
#        [-0.5269958]], dtype=float32), 5.001305], 4.1323214]
# 9924 [[array([[ 1.46841  ],
#        [ 1.0255674],
#        [-0.5269853]], dtype=float32), 5.001305], 4.13212]
# 9925 [[array([[ 1.4684156],
#        [ 1.0255512],
#        [-0.5269748]], dtype=float32), 5.001305], 4.131978]
# 9926 [[array([[ 1.4684212],
#        [ 1.025535 ],
#        [-0.5269643]], dtype=float32), 5.001305], 4.131835]
# 9927 [[array([[ 1.4684268],
#        [ 1.0255188],
#        [-0.5269539]], dtype=float32), 5.001305], 4.1316504]
# 9928 [[array([[ 1.4684324],
#        [ 1.0255026],
#        [-0.5269434]], dtype=float32), 5.001305], 4.1315184]
# 9929 [[array([[ 1.468438  ],
#        [ 1.0254864 ],
#        [-0.52693295]], dtype=float32), 5.001305], 4.1313467]
# 9930 [[array([[ 1.4684436 ],
#        [ 1.0254701 ],
#        [-0.52692246]], dtype=float32), 5.001305], 4.131178]
# 9931 [[array([[ 1.4684492 ],
#        [ 1.0254539 ],
#        [-0.52691203]], dtype=float32), 5.001305], 4.1310167]
# 9932 [[array([[ 1.4684548],
#        [ 1.0254377],
#        [-0.5269016]], dtype=float32), 5.001305], 4.1308713]
# 9933 [[array([[ 1.4684604],
#        [ 1.0254215],
#        [-0.5268911]], dtype=float32), 5.001305], 4.130697]
# 9934 [[array([[ 1.468466 ],
#        [ 1.0254054],
#        [-0.5268806]], dtype=float32), 5.001305], 4.130546]
# 9935 [[array([[ 1.4684716],
#        [ 1.0253892],
#        [-0.5268702]], dtype=float32), 5.001305], 4.1303787]
# 9936 [[array([[ 1.4684772 ],
#        [ 1.025373  ],
#        [-0.52685976]], dtype=float32), 5.001305], 4.130212]
# 9937 [[array([[ 1.4684829],
#        [ 1.0253568],
#        [-0.5268493]], dtype=float32), 5.001305], 4.130046]
# 9938 [[array([[ 1.4684885 ],
#        [ 1.0253407 ],
#        [-0.52683884]], dtype=float32), 5.001305], 4.1298914]
# 9939 [[array([[ 1.468494 ],
#        [ 1.0253246],
#        [-0.5268284]], dtype=float32), 5.001305], 4.1297464]
# 9940 [[array([[ 1.4684997],
#        [ 1.0253084],
#        [-0.526818 ]], dtype=float32), 5.001305], 4.1295767]
# 9941 [[array([[ 1.4685053 ],
#        [ 1.0252922 ],
#        [-0.52680755]], dtype=float32), 5.001305], 4.129395]
# 9942 [[array([[ 1.4685109],
#        [ 1.0252761],
#        [-0.5267971]], dtype=float32), 5.001305], 4.129283]
# 9943 [[array([[ 1.4685165],
#        [ 1.0252599],
#        [-0.5267867]], dtype=float32), 5.001305], 4.1290884]
# 9944 [[array([[ 1.4685221 ],
#        [ 1.0252438 ],
#        [-0.52677625]], dtype=float32), 5.001305], 4.12893]
# 9945 [[array([[ 1.4685277],
#        [ 1.0252277],
#        [-0.5267658]], dtype=float32), 5.001305], 4.128768]
# 9946 [[array([[ 1.4685333],
#        [ 1.0252115],
#        [-0.5267554]], dtype=float32), 5.001305], 4.1286325]
# 9947 [[array([[ 1.4685389 ],
#        [ 1.0251954 ],
#        [-0.52674496]], dtype=float32), 5.001305], 4.1284585]
# 9948 [[array([[ 1.4685445 ],
#        [ 1.0251791 ],
#        [-0.52673453]], dtype=float32), 5.001305], 4.128282]
# 9949 [[array([[ 1.4685501],
#        [ 1.025163 ],
#        [-0.5267241]], dtype=float32), 5.001305], 4.1281276]
# 9950 [[array([[ 1.4685557 ],
#        [ 1.0251468 ],
#        [-0.52671367]], dtype=float32), 5.001305], 4.127969]
# 9951 [[array([[ 1.4685613 ],
#        [ 1.0251307 ],
#        [-0.52670324]], dtype=float32), 5.001305], 4.127814]
# 9952 [[array([[ 1.4685669],
#        [ 1.0251147],
#        [-0.5266928]], dtype=float32), 5.001305], 4.1276226]
# 9953 [[array([[ 1.4685725],
#        [ 1.0250984],
#        [-0.5266824]], dtype=float32), 5.001305], 4.1274967]
# 9954 [[array([[ 1.4685781 ],
#        [ 1.0250823 ],
#        [-0.52667195]], dtype=float32), 5.001305], 4.1273518]
# 9955 [[array([[ 1.4685837],
#        [ 1.0250663],
#        [-0.5266615]], dtype=float32), 5.001305], 4.1271667]
# 9956 [[array([[ 1.4685893],
#        [ 1.02505  ],
#        [-0.5266511]], dtype=float32), 5.001305], 4.127021]
# 9957 [[array([[ 1.4685949 ],
#        [ 1.0250338 ],
#        [-0.52664065]], dtype=float32), 5.001305], 4.126849]
# 9958 [[array([[ 1.4686005],
#        [ 1.0250177],
#        [-0.5266302]], dtype=float32), 5.001305], 4.1266923]
# 9959 [[array([[ 1.4686061],
#        [ 1.0250015],
#        [-0.5266198]], dtype=float32), 5.001305], 4.126533]
# 9960 [[array([[ 1.4686117 ],
#        [ 1.0249854 ],
#        [-0.52660936]], dtype=float32), 5.001305], 4.126359]
# 9961 [[array([[ 1.4686173 ],
#        [ 1.0249692 ],
#        [-0.52659893]], dtype=float32), 5.001305], 4.1262193]
# 9962 [[array([[ 1.4686229],
#        [ 1.0249531],
#        [-0.5265885]], dtype=float32), 5.001305], 4.126045]
# 9963 [[array([[ 1.4686285 ],
#        [ 1.024937  ],
#        [-0.52657807]], dtype=float32), 5.001305], 4.1259027]
# 9964 [[array([[ 1.4686341 ],
#        [ 1.0249208 ],
#        [-0.52656764]], dtype=float32), 5.001305], 4.1257105]
# 9965 [[array([[ 1.4686397],
#        [ 1.0249047],
#        [-0.5265572]], dtype=float32), 5.001305], 4.125554]
# 9966 [[array([[ 1.4686453],
#        [ 1.0248885],
#        [-0.5265468]], dtype=float32), 5.001305], 4.125405]
# 9967 [[array([[ 1.4686509 ],
#        [ 1.0248724 ],
#        [-0.52653635]], dtype=float32), 5.001305], 4.125269]
# 9968 [[array([[ 1.4686565],
#        [ 1.0248563],
#        [-0.5265259]], dtype=float32), 5.001305], 4.125104]
# 9969 [[array([[ 1.468662 ],
#        [ 1.0248401],
#        [-0.5265155]], dtype=float32), 5.001305], 4.1249456]
# 9970 [[array([[ 1.4686676 ],
#        [ 1.024824  ],
#        [-0.52650505]], dtype=float32), 5.001305], 4.124786]
# 9971 [[array([[ 1.4686732],
#        [ 1.0248079],
#        [-0.5264946]], dtype=float32), 5.001305], 4.12461]
# 9972 [[array([[ 1.4686787],
#        [ 1.0247918],
#        [-0.5264842]], dtype=float32), 5.001305], 4.124442]
# 9973 [[array([[ 1.4686842 ],
#        [ 1.0247757 ],
#        [-0.52647376]], dtype=float32), 5.001305], 4.124284]
# 9974 [[array([[ 1.4686898],
#        [ 1.0247597],
#        [-0.5264633]], dtype=float32), 5.001305], 4.1241064]
# 9975 [[array([[ 1.4686953],
#        [ 1.0247436],
#        [-0.5264529]], dtype=float32), 5.001305], 4.123967]
# 9976 [[array([[ 1.4687008 ],
#        [ 1.0247275 ],
#        [-0.52644247]], dtype=float32), 5.001305], 4.1238093]
# 9977 [[array([[ 1.4687063 ],
#        [ 1.0247114 ],
#        [-0.52643204]], dtype=float32), 5.001305], 4.1236653]
# 9978 [[array([[ 1.4687117],
#        [ 1.0246953],
#        [-0.5264216]], dtype=float32), 5.001305], 4.123478]
# 9979 [[array([[ 1.4687173],
#        [ 1.0246792],
#        [-0.5264112]], dtype=float32), 5.001305], 4.12334]
# 9980 [[array([[ 1.4687228 ],
#        [ 1.0246631 ],
#        [-0.52640074]], dtype=float32), 5.001305], 4.123172]
# 9981 [[array([[ 1.4687283],
#        [ 1.024647 ],
#        [-0.5263903]], dtype=float32), 5.001305], 4.1230307]
# 9982 [[array([[ 1.4687338],
#        [ 1.0246309],
#        [-0.5263799]], dtype=float32), 5.001305], 4.1228423]
# 9983 [[array([[ 1.4687393 ],
#        [ 1.0246148 ],
#        [-0.52636945]], dtype=float32), 5.001305], 4.1226716]
# 9984 [[array([[ 1.4687448],
#        [ 1.0245987],
#        [-0.526359 ]], dtype=float32), 5.001305], 4.1225405]
# 9985 [[array([[ 1.4687502],
#        [ 1.0245826],
#        [-0.5263486]], dtype=float32), 5.001305], 4.122353]
# 9986 [[array([[ 1.4687558 ],
#        [ 1.0245665 ],
#        [-0.52633816]], dtype=float32), 5.001305], 4.122202]
# 9987 [[array([[ 1.4687613],
#        [ 1.0245504],
#        [-0.5263277]], dtype=float32), 5.001305], 4.1220474]
# 9988 [[array([[ 1.4687668],
#        [ 1.0245343],
#        [-0.5263173]], dtype=float32), 5.001305], 4.121889]
# 9989 [[array([[ 1.4687723 ],
#        [ 1.0245183 ],
#        [-0.52630687]], dtype=float32), 5.001305], 4.121721]
# 9990 [[array([[ 1.4687779 ],
#        [ 1.0245022 ],
#        [-0.52629644]], dtype=float32), 5.001305], 4.12157]
# 9991 [[array([[ 1.4687834],
#        [ 1.0244861],
#        [-0.526286 ]], dtype=float32), 5.001305], 4.1214075]
# 9992 [[array([[ 1.4687889],
#        [ 1.02447  ],
#        [-0.5262756]], dtype=float32), 5.001305], 4.1212645]
# 9993 [[array([[ 1.4687945 ],
#        [ 1.0244539 ],
#        [-0.52626514]], dtype=float32), 5.001305], 4.1211104]
# 9994 [[array([[ 1.4688   ],
#        [ 1.0244378],
#        [-0.5262547]], dtype=float32), 5.001305], 4.120915]
# 9995 [[array([[ 1.4688054],
#        [ 1.0244217],
#        [-0.5262443]], dtype=float32), 5.001305], 4.1207743]
# 9996 [[array([[ 1.4688109 ],
#        [ 1.0244056 ],
#        [-0.52623385]], dtype=float32), 5.001305], 4.12061]
# 9997 [[array([[ 1.4688164],
#        [ 1.0243895],
#        [-0.5262234]], dtype=float32), 5.001305], 4.120452]
# 9998 [[array([[ 1.4688219],
#        [ 1.0243734],
#        [-0.526213 ]], dtype=float32), 5.001305], 4.120318]
# 9999 [[array([[ 1.4688274 ],
#        [ 1.0243573 ],
#        [-0.52620256]], dtype=float32), 5.001305], 4.12013]

# %%
print(sess.run(hypothesis, feed_dict = {X: x_data}))
# Out:
# [[154.70909]
#  [182.80887]
#  [181.58524]
#  [193.77551]
#  [142.99911]]
